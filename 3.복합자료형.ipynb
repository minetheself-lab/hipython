# %% [markdown]
# #리스트
# [ ] 대괄호로 여러 값을 하나의 변수로 묶어주는 자료구조

# %%
score=[20,30,50,90,100]
score [0] #첫번째 학생 점수
score[4], score[-1]#마지막 학생점수
# Out:
# (100, 100)

# %%
#리스트는 순서가 있다. - 인덱싱과 슬라이싱이 있다.
fruits=['사과', '바나나', '포도']
mixed=['사과', 20, '바나나', 30, True]
matrix=[[1,2], [3,4]]

# %%
matrix[1][1]
# Out:
# 4

# %%
s_list='Hello'
s_list[0]='h' # 문자열은 변경불가
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 s_list='Hello'
# ----> 2 s_list[0]='h' # 문자열은 변경불가
#
# TypeError: 'str' object does not support item assignment

# %%
n_list=list(s_list)
type(n_list)
n_list
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
n_list[0]='h'
n_list
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
''.join(n_list)
# Out:
# 'hello'

# %%
list [1,2,3,4]
# Out:
# list[1, 2, 3, 4]

# %%
a=range(5)
list(a)
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(2,10,3))
# Out:
# [2, 5, 8]

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ## 복사, 얕은 복사 shallow copy

# %%
score=[10,20,30]
new_score=score
new_score
# Out:
# [10, 20, 30]

# %%
new_score[0]=100
new_score
# Out:
# [100, 20, 30]

# %% [markdown]
# ## 깊은 복사 deep copy

# %%
import copy
new_score_1=copy.copy(score)
new_score_1[1]=99
new_score_1, score
# Out:
# ([100, 99, 30], [100, 20, 30])

# %% [markdown]
# ## 리스트의연산

# %%
lunch_1=['찌게', '면', '샐러드']
lunch_2=['파스타', '라자냐']
lunch_1+lunch_2
# Out:
# ['찌게', '면', '샐러드', '파스타', '라자냐']

# %%
lunch_1*2
# Out:
# ['찌게', '면', '샐러드', '찌게', '면', '샐러드']

# %%
del lunch_1[0]
lunch_1
# Out:
# ['면', '샐러드']

# %%
'샐러드' in lunch_1
# Out:
# True

# %%
'a' in 'abcd'
# Out:
# True

# %%
# 연습문제
snack_box= ['홈런볼']
#먹고 싶은 간식을 입력받아서 추가하세요.

# %%
new_snack=[input('먹고 싶은 간식을 입력하세요.')]
snack_box += new_snack
snack_box
# Out:
# 먹고 싶은 간식을 입력하세요. 파이
# ['홈런볼', '파이']

# %%
del_n=int(input('빼고 싶은 간식이 있으면 번호를 입력하세요.'))-1
del snack_box[del_n]
snack_box
# Out:
# 빼고 싶은 간식이 있으면 번호를 입력하세요. 0
# ['홈런볼']

# %%
f_name=input('찾고 있는 간식이름을 입력하세요')
if f_name in snack_box:
    print('있어요!!')
else:
    print ('없네요...')
# Out:
# 찾고 있는 간식이름을 입력하세요 파이
# 있어요!!

# %% [markdown]
# ## ==, is

# %%
lunch_1=['주먹밥', '치킨', '칼국수']
lunch_2=['주먹밥', '치킨', '칼국수']
lunch_1==lunch_2
# Out:
# True

# %%
id(lunch_1)==id(lunch_2)
# Out:
# False

# %%
lunch_1 is lunch_2
# Out:
# False

# %%
students=[{'num':'1', 'name':'hong', 'math':90, 'sci':60, 'eng': 70},
          {'num':'2', 'name':'kong', 'math':70, 'sci':70, 'eng': 70},
          {'num':'3', 'name':'gang', 'math':95, 'sci':60, 'eng': 80}]

# %%
students[2]['num']
# Out:
# '3'

# %%
for stu in students:
    print(stu['name'])
# Out:
# hong
# kong
# gang

# %%
for stu in students:
    stu ['total']=stu['sci']+stu['math']+stu['eng']
    print(stu)
# Out:
# {'num': '1', 'name': 'hong', 'math': 90, 'sci': 60, 'eng': 70, 'total': 220}
# {'num': '2', 'name': 'kong', 'math': 70, 'sci': 70, 'eng': 70, 'total': 210}
# {'num': '3', 'name': 'gang', 'math': 95, 'sci': 60, 'eng': 80, 'total': 235}

# %%
for stu in students:
    stu ['avg']=(stu['sci']+stu['math']+stu['eng'])/3
    print(stu)
# Out:
# {'num': '1', 'name': 'hong', 'math': 90, 'sci': 60, 'eng': 70, 'total': 220, 'avg': 73.33333333333333}
# {'num': '2', 'name': 'kong', 'math': 70, 'sci': 70, 'eng': 70, 'total': 210, 'avg': 70.0}
# {'num': '3', 'name': 'gang', 'math': 95, 'sci': 60, 'eng': 80, 'total': 235, 'avg': 78.33333333333333}

# %%
for stu in students:
    stu ['avg']=stu['total']/3

# %%
for stu in students:
    print(stu)
# Out:
# {'num': '1', 'name': 'hong', 'math': 90, 'sci': 60, 'eng': 70, 'total': 220, 'avg': (73.33333333333333, 2)}
# {'num': '2', 'name': 'kong', 'math': 70, 'sci': 70, 'eng': 70, 'total': 210, 'avg': (70.0, 2)}
# {'num': '3', 'name': 'gang', 'math': 95, 'sci': 60, 'eng': 80, 'total': 235, 'avg': (78.33333333333333, 2)}

# %% [markdown]
# # 리스트의 정렬

# %%
num=[5,1,2,4,6,8]
num.sort()

# %%
num
# Out:
# [1, 2, 4, 5, 6, 8]

# %%
num=[5,1,2,4,6,8]
new_num=sorted(num)

# %%
num
# Out:
# [5, 1, 2, 4, 6, 8]

# %%
new_num
# Out:
# [1, 2, 4, 5, 6, 8]

# %%
new_stu=sorted(stu{'total'})
# Out:
#   Cell In[29], line 1
#     new_stu=sorted(stu{'total'})
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
fruits=['멜론', '딸기', '복숭아', '사과', '감']
fruits.append('멜론')
fruits
# Out:
# ['멜론', '딸기', '복숭아', '사과', '감', '멜론']

# %%
fruits.append(1)
fruits
# Out:
# ['멜론', '딸기', '복숭아', '사과', '감', '멜론', 1, 1, 1]

# %%
fruits.insert(2,'수박')
fruits
# Out:
# ['멜론', '딸기', '수박', '복숭아', '사과', '감', '멜론', 1, 1]

# %%
dir(fruits)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
fruits.remove('수박')
fruits
# Out:
# ['멜론', '딸기', '복숭아', '사과', '감', '멜론', 1, 1]

# %%
fruits.pop('1')
fruits
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 fruits.pop('1')
#       2 fruits
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
data=list(range(-100,100))
print(len(data))
# Out:
# 200

# %%
# 리스트에 양수만 남기는 것을 목표로
filtered=[]
for x data:
    if x>=0:
        filtered.append(x)

# %%
aaa= [1,3,5,4,2]

# %%
new_aaa=sorted(aaa, reverse=True)
new_aaa
# Out:
# [5, 4, 3, 2, 1]

# %%
bbb=['Life','is','too','short']
" ".join(bbb)
# Out:
# 'Life is too short'

# %%
num11=[1, 3, 5, 7, 9]
first=num11.pop(0)
first
# Out:
# 1

# %%
tu1=1,2,3
tu1
# Out:
# (1, 2, 3)

# %%
t3=(2)
t3, type(t3)
# Out:
# (2, int)

# %%
t3=(2,)
t3,type(t3)
# Out:
# ((2,), tuple)

# %%
t= (10,20,30, 40,50)
t[1], t[-1]
# Out:
# (20, 50)

# %%
t[2:4]
# Out:
# (30, 40)

# %%
t_list=list(t)
t_list[0]=20
t_new=tuple(t_list)
t_new
# Out:
# (20, 20, 30, 40, 50)

# %%
nums=[1,2,3]
nums
# Out:
# [1, 2, 3]

# %%
nums=(1,2,3) #패킹
x,y,z=nums
x,y,z, nums #언패킹
# Out:
# (1, 2, 3, (1, 2, 3))

# %%
name, age, grade=('hong', 20, '1학년')

# %%
tmp =x
x=y
y=tmp

# %%
x,y=y,x

# %% [markdown]
# # 딕셔너리

# %%
person={"이름":'alice', 'age':25, 'city':'서울'}
person_1={"이름":'bob', 'age':30, 'city':'부산'}

# %%
person['이름']
# Out:
# 'alice'

# %%
person_1['이름']
# Out:
# 'bob'

# %%
for per in person.values():
    print(per)
# Out:
# alice
# 25
# 서울

# %%
for per, val in person.items():
    print (per,val)
# Out:
# 이름 alice
# age 25
# city 서울

# %%
person["직업"]="개발자"
print(person.keys())
print(person.values())
print(person.items())
print(person.pop('age'))
# Out:
# dict_keys(['이름', 'age', 'city', '직업'])
# dict_values(['alice', 25, '서울', '개발자'])
# dict_items([('이름', 'alice'), ('age', 25), ('city', '서울'), ('직업', '개발자')])
# 25

# %% [markdown]
# # 집합

# %%
집합1=set ([1,2,3,4])
집합1
# Out:
# {1, 2, 3, 4}

# %%
집합2= set ([1,2,3,4, 4,3,])
집합2
# Out:
# {1, 2, 3, 4}

# %%
dir(집합3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 dir(집합3)
#
# NameError: name '집합3' is not defined

# %%
시가총액='298조'
현재가='50,000원'
PER='15.70'
print(시가총액,현재가,PER)
# Out:
# 298조 50,000원 15.70

# %%
list=[시가총액, 현재가, PER]
' '.join(list)
# Out:
# '298조 50,000원 15.70'

# %% [markdown]
# #crud 프로그램
# 1. 함수도출: CRUD 기본
# 2. 함수구현
# 3. 문제점도출- 함수 리팩토링
# 4. 전체흐름 구현 함수

# %%
# 간식박스 생성함수
def make_snackbox():
    snackbox=['두쫀쿠']
    return snackbox
    
# 간식박스 추가함수
def add_snackbox(sbox):
    make_msg=input('먹고 싶은 간식을 추가하세요. 쉼표(,)로 연결하세요').split(',')
    sbox.append(make_msg)
    print(sbox)
    return sbox
# 메뉴출력
def display_menu():
    print("1. 간식추가")
    print("2. 간식박스 확인")
    print("3. 간식제거")

# 전체보기
# 삭제 함수
# 수정함수

# %%
#서비스의 흐름
snack_box=make_snackbox()
print('간식박스 생성완료', snack_box)
dispaly_menu()
menu_no=input('메뉴를 선택하세요')
if menu_no=='1':
    add_snackbox(snack_box)
elif menu_no=='2':
    display_snackbox(snack_box)
# Out:
# 간식박스 생성완료 ['두쫀쿠']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 snack_box=make_snackbox()
#       3 print('간식박스 생성완료', snack_box)
# ----> 4 dispaly_menu()
#       5 menu_no=input('메뉴를 선택하세요')
#       6 if menu_no=='1':
#
# NameError: name 'dispaly_menu' is not defined

# %%
# 간식박스 생성함수
def make_snackbox():
    snackbox=['두쫀쿠']
    return snackbox

# %%
# 간식박스 추가함수
def add_snackbox(sbox):
    make_msg=input('먹고 싶은 간식을 추가하세요. 쉼표(,)로 연결하세요').split(',')
    sbox.extend(make_msg)
    print(sbox)
    return sbox

# %%
# 메뉴출력
def display_menu():
    print("1. 간식추가")
    print("2. 간식박스 확인")
    print("3. 간식제거")
    print("4. 주문확정")

# %%
#서비스의 흐름
snack_box=make_snackbox()
print('간식박스 생성완료', snack_box)
dispaly_menu()
menu_no=input('메뉴를 선택하세요')
if menu_no=='1':
    add_snackbox(snack_box)
elif menu_no=='2':
    display_snackbox(snack_box)
# Out:
# 간식박스 생성완료 ['두쫀쿠']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 snack_box=make_snackbox()
#       3 print('간식박스 생성완료', snack_box)
# ----> 4 dispaly_menu()
#       5 menu_no=input('메뉴를 선택하세요')
#       6 if menu_no=='1':
#
# NameError: name 'dispaly_menu' is not defined

# %%
add_snackbox(aaa):
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 add_snackbox(aaa)
#
# NameError: name 'aaa' is not defined

# %%
def make_snackbox():
    snackbox = ['두쫀쿠', '홈런볼']
    return snackbox
print(make_snackbox())
# Out:
# ['두쫀쿠', '홈런볼']

# %%
def add_snackbox(sbox): #간식리스트
    make_msg = input('먹고 싶은 간식을 추가하세요. 쉼표(,)로 연결하세요').split(',')
    sbox.extend(make_msg)
    #print(sbox)
    return sbox

# %%
# 간식박스 생성 함수
def make_snackbox():
    snackbox = ['두쫀쿠', '홈런볼']
    return snackbox
aaa=make_snackbox()
print (aaa)
# Out:
# ['두쫀쿠', '홈런볼']

# %%
# 간식박스 추가함수
def add_snackbox(sbox): #간식리스트
    make_msg = input('먹고 싶은 간식을 추가하세요. 쉼표(,)로 연결하세요').split(',')
    sbox.extend(make_msg)
    #print(sbox)
    return sbox
add_snackbox(aaa)
print (aaa)
# Out:
# 먹고 싶은 간식을 추가하세요. 쉼표(,)로 연결하세요 쿠키
# ['두쫀쿠', '홈런볼', '쿠키']

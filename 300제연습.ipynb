# %%
kmh=float(input('kmh를 입력하세요:  '))
mph=0.6214*kmh
print('mph:', mph)
# Out:
# kmh를 입력하세요:   222
# mph: 137.9508

# %%
kmh=int(input("현재 속도를 km/h로 입력하세요."))
a_value=0.6214 #상수
print(type(a_value), type(kmh))
mph=a_value*kmh
print (f' {mph}')
# Out:
# 현재 속도를 km/h로 입력하세요. 222
# <class 'float'> <class 'int'>
#  137.9508

# %%
kmh=int(input("현재 속도를 km/h로 입력하세요."))
if kmh>0:
    mph=a_value*kmh
    print(f' {kmh}를 mph로 변환하면 {mph}입니다.')
else: 
    print('속도는 양수로 입력하세요')
# Out:
# 현재 속도를 km/h로 입력하세요. 222
#  222를 mph로 변환하면 137.9508입니다.

# %%
import calendar
theyear=int(input('연도를 입력하세요.'))
themonth=int(input('월을 입력하세요(1~12)'))

#if themonth >0 and themonth <13:
if 0 <themonth <13:
   print(calendar.month(theyear, themonth))
else:
   print ('1월부터 12월 사이의 정수를 입력하세요.')
# Out:
# 연도를 입력하세요. 111
# 월을 입력하세요(1~12) 22
# 1월부터 12월 사이의 정수를 입력하세요.

# %%
num_1=float(input('실수(예.1.1)를 입력하세요.'))
num_2=float(input('실수 (예.1.222)를 한번 더 입력하세요.'))

mul=num_1*num_2
addition=num_1+num_2
output=f'First is {num_1}, and second is {num_2} '\
+f'So, Multiplication = {mul:.3f},'\
+f' addition = {addition:.2f}'
print(output)
# Out:
# 실수(예.1.1)를 입력하세요. 2.333
# 실수 (예.1.222)를 한번 더 입력하세요. 4.56677
# First is 2.333, and second is 4.56677 So, Multiplication = 10.654, addition = 6.90

# %%
a=10
b=20
c=33
a, type(a)
# Out:
# (10, int)

# %%
a=11
b=7
Area=a*b
Perimeter=2*(a+b)
print(Area, Perimeter)
# Out:
# 77 36

# %%
x=int(input('홀짝을 판별할 숫자를 입력하세요'))
나머지=x%2
if 나머지 == 1: #비교 == 같다
    print(f'{x}는 홀수 입니다.')
else:
    print(f'{x}는 짝수입니다.')
# Out:
# 홀짝을 판별할 숫자를 입력하세요 33
# 33는 홀수 입니다.

# %%
a=20
area= 6*(a**2)
volume=a**3
print(area, volume)
# Out:
# 2400 8000

# %%
x=4; y=2;
z=abs(x-y)*(x+y)
print(z)
# Out:
# 12

# %%
시가총액='298조'
현재가='50,000원'
PER='15.79'
print('시가총액', '현재가', 'PER')
# Out:
# 시가총액 현재가 PER

# %%
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 298000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s='hello'
t='python'
print (s+'!', t)
# Out:
# hello! python

# %%
a="Hello World"
print(a)
# Out:
# Hello World

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리질렀다. "도둑이야"')
# Out:
# 신씨가 소리질렀다. "도둑이야"

# %%
print("C:\\Windows")
# Out:
# C:\Windows

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("naver;kakao;sk;samsung")
# Out:
# naver;kakao;sk;samsung

# %%
print("naver", "kakao", "samsung", sep=";")
# Out:
# naver;kakao;samsung

# %%
print ("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
aaa="naver;kakao;sk;samsung"
print(aaa)
# Out:
# naver;kakao;sk;samsung

# %%
print(aaa, sep=";")
# Out:
# naver;kakao;sk;samsung

# %%
print('naver', 'kakao', 'sk', 'samsung', sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end="");print('second')
# Out:
# firstsecond

# %%
aaa=5/3
print(aaa)
# Out:
# 1.6666666666666667

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %%
삼성전자 = 50000
총평가금액 = 삼성전자 * 10
print(총평가금액)
# Out:
# 500000

# %%
시가총액='298조'
현재가='50,000원'
PER='15.79'
print(시가총액, 현재가, PER)
# Out:
# 298조 50,000원 15.79

# %%
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 298000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s="hello"
t="python"
print(s+"!",t)
# Out:
# hello! python

# %%
print(2+2*3)
# Out:
# 8

# %%
a="132"
print (type(a))
# Out:
# <class 'str'>

# %%
num_str=720
print(num_str, type(num_str))
# Out:
# 720 <class 'int'>

# %%
num_str="720"
num_int=int(num_str)
print(num_int, type(num_int))
# Out:
# 720 <class 'int'>

# %%
num=100
num_str=str(num)
print(num_str, type(num_str))
# Out:
# 100 <class 'str'>

# %%
st_1="15.79"
result=float(st_1)
print(result, type(result))
# Out:
# 15.79 <class 'float'>

# %%
data = "15.79"
data = float(data)
print(data, type(data))
# Out:
# 15.79 <class 'float'>

# %%
str_01="15.70"
aaa1=float(str_01)
print(aaa1, type(aaa1))
# Out:
# 15.7 <class 'float'>

# %%
year="2020"
print(int(year)-3)
print(int(year)-2)
print(int(year)-1)
# Out:
# 2017
# 2018
# 2019

# %%
월=48584
총금액=월*36
print(총금액)
# Out:
# 1749024

# %%
letters='python'
words=letters.split()
print(words)
# Out:
# ['python']

# %%
a="132"
print(type(a))
# Out:
# <class 'str'>

# %%
num_str=int("720")
print(type(num_str))
# Out:
# <class 'int'>

# %%
num=100
num_st="num"
print(num_st, type(num_st))
# Out:
# num <class 'str'>

# %%
num=100
result=str(num)
print(result, type(result))
# Out:
# 100 <class 'str'>

# %%
num="15.79"
result=float(num)
print (result, type(result))
# Out:
# 15.79 <class 'float'>

# %%
year="2020"
year_int=int(year)
print(year_int-2, year_int-1, year_int)
# Out:
# 2018 2019 2020

# %%
air_month=48584
insta=36
total=air_month*insta
print(total)
# Out:
# 1749024

# %%
letters='python'
print (letters[0], letters[2])
# Out:
# p t

# %%
license_plate="24가 2210"
print(license_plate[-4:])
# Out:
# 2210

# %%
string="홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀

# %%
string="python"
print(string[::-1])
# Out:
# nohtyp

# %%
phone_number="010-1111-2222"
modified_phone_number=phone_number.replace('-', ' ')
print(modified_phone_number)
# Out:
# 010 1111 2222

# %%
phone_number = "010-1111-2222"
phone_number1= phone_number.replace('-', '')
print(phone_number1)
# Out:
# 01011112222

# %%
url = "http://sharebook.kr"
url_split = url.split('.')
print(url_split[1])
# Out:
# kr

# %%
lang = 'python'
lang_2 = lang [0]
print (lang_2)
# Out:
# p

# %%
string = 'abcdfe2a354a32a'
string_a = (string [0]).upper()
print(string_a)
# Out:
# A

# %%
string = 'abcdfe2a354a32a'
string = string.replace('a', 'A')
print(string)
# Out:
# Abcdfe2A354A32A

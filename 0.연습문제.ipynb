# %%
print ("Hello World")
# Out:
# Hello World

# %%
print ("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print ("""신씨가 소리질렀다. "도둑이야".""")
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
print('신씨가 소리질렀다. "도둑이야."')
# Out:
# 신씨가 소리질렀다. "도둑이야."

# %%
print ('"C:"\"Windows"')
# Out:
# "C:""Windows"

# %%
print ("C:\\Windows")
# Out:
# C:\Windows

# %%
print ("C:\Windows")
# Out:
# C:\Windows
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5104\69065316.py:1: SyntaxWarning: invalid escape sequence '\W'
#   print ("C:\Windows")

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print ("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
print ("naver;kakao;sk;samsung")
# Out:
# naver;kakao;sk;samsung

# %%
print ("naver", "kakao", "sk", "samsung", sep=";")
# Out:
# naver;kakao;sk;samsung

# %%
print("naver", "kakao", "sk", "samsung", sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
print("first");print("second"), end:";")
# Out:
#   Cell In[17], line 1
#     print("first");print("second"), end:";")
#                                            ^
# SyntaxError: unmatched ')'

# %%
print("first"), end="print("second")")
# Out:
#   Cell In[21], line 1
#     print("first"), end="print("second")")
#                                          ^
# SyntaxError: unmatched ')'

# %%
print("first", end=" "); print("second")
# Out:
# first second

# %%
print(5,3, sep="/")
# Out:
# 5/3

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %%
print("5/3")
# Out:
# 5/3

# %%
삼성전자=50,000
a=삼성전자*10
print("총평가금액=" a)
# Out:
#   Cell In[27], line 3
#     print("총평가금액=" a)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

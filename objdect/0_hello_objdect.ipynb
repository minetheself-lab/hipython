# %%
import torch
print('PyTorch:', torch.__version__)
print('CUDA 사용 가능:', torch.cuda.is_available())
print('GPU:', torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.6.0+cu124
# CUDA 사용 가능: True
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.31  Python-3.11.15 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 165.5/475.9 GB disk)

# %% [markdown]
# # 로보플로우 인퍼런스 api 사용하기

# %%
from inference_sdk import InferenceHTTPClient
# 연결 클라이언트 생성
CLIENT = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="SW2Koe7EIHo2SxuS1oRf"
)
# 추론요청
result = CLIENT.infer('sample_0330.png', model_id="rock-paper-scissors-sxsw/14")
result
# Out:
# {'inference_id': 'ee42d891-a090-4e83-95fb-4e0eb1b8c391',
#  'time': 0.09040113000082783,
#  'image': {'width': 561, 'height': 462},
#  'predictions': [{'x': 390.5,
#    'y': 361.0,
#    'width': 163.0,
#    'height': 162.0,
#    'confidence': 0.9303890466690063,
#    'class': 'Rock',
#    'class_id': 1,
#    'detection_id': '9ec6162b-704a-47d7-a605-66cdeb091588'},
#   {'x': 400.5,
#    'y': 126.0,
#    'width': 237.0,
#    'height': 206.0,
#    'confidence': 0.7863779067993164,
#    'class': 'Scissors',
#    'class_id': 2,
#    'detection_id': '22f2d0e7-e1a1-4f7d-8c05-ffec4d99bacf'},
#   {'x': 153.5,
#    'y': 347.5,
#    'width': 233.0,
#    'height': 207.0,
#    'confidence': 0.6221094131469727,
#    'class': 'Scissors',
#    'class_id': 2,
#    'detection_id': '81c6f701-213c-408e-90a0-5afd74261c31'}]}

# %% [markdown]
# # 이미지 시각화

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('sample_0330.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
import cv2
import matplotlib.pyplot as plt

#filename = 'sample_0330.png'
#result = CLIENT.infer(filename, model_id="rock-paper-scissors-sxsw/14")
#img = cv2.imread(filename)

for pred in result["predictions"]:
    x, y = pred['x'], pred['y']
    width, height = pred['width'], pred['height']
    conf = pred['confidence']
    cls = pred['class']
    x1, y1 = int(x-width/2), int(y-height/2)
    x2, y2 = int(x+width/2), int(y+height/2)
    cv2.rectangle(img, (x1,y1), (x2, y2), (0,0,255), 2)
    cv2.putText(img, f'{cls} {conf:.4f}', (x1,y1), cv2.FONT_HERSHEY_PLAIN, 2, (0,0,255))

plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
img=cv2.imread('sample_0330-1.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
import cv2
import matplotlib.pyplot as plt

#filename = 'sample_0330.png'
#result = CLIENT.infer(filename, model_id="rock-paper-scissors-sxsw/14")
#img = cv2.imread(filename)

for pred in result["predictions"]:
    x, y = pred['x'], pred['y']
    width, height = pred['width'], pred['height']
    conf = pred['confidence']
    cls = pred['class']
    x1, y1 = int(x-width/2), int(y-height/2)
    x2, y2 = int(x+width/2), int(y+height/2)
    cv2.rectangle(img, (x1,y1), (x2, y2), (0,0,255), 2)
    cv2.putText(img, f'{cls} {conf:.4f}', (x1,y1), cv2.FONT_HERSHEY_PLAIN, 2, (0,0,255))

plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
img=cv2.imread('sample_0330-2.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
import cv2
import matplotlib.pyplot as plt

#filename = 'sample_0330.png'
#result = CLIENT.infer(filename, model_id="rock-paper-scissors-sxsw/14")
#img = cv2.imread(filename)

for pred in result["predictions"]:
    x, y = pred['x'], pred['y']
    width, height = pred['width'], pred['height']
    conf = pred['confidence']
    cls = pred['class']
    x1, y1 = int(x-width/2), int(y-height/2)
    x2, y2 = int(x+width/2), int(y+height/2)
    cv2.rectangle(img, (x1,y1), (x2, y2), (0,0,255), 2)
    cv2.putText(img, f'{cls} {conf:.4f}', (x1,y1), cv2.FONT_HERSHEY_PLAIN, 2, (0,0,255))

plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
img=cv2.imread('sample0330-3.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
import cv2
import matplotlib.pyplot as plt

#filename = 'sample_0330.png'
#result = CLIENT.infer(filename, model_id="rock-paper-scissors-sxsw/14")
#img = cv2.imread(filename)

for pred in result["predictions"]:
    x, y = pred['x'], pred['y']
    width, height = pred['width'], pred['height']
    conf = pred['confidence']
    cls = pred['class']
    x1, y1 = int(x-width/2), int(y-height/2)
    x2, y2 = int(x+width/2), int(y+height/2)
    cv2.rectangle(img, (x1,y1), (x2, y2), (0,0,255), 2)
    cv2.putText(img, f'{cls} {conf:.4f}', (x1,y1), cv2.FONT_HERSHEY_PLAIN, 2, (0,0,255))

plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

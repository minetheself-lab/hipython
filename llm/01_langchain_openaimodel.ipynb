# %%
# 처리 방식
invoke()
batch()
stream()

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-4o-mini")

# invoke() - 단일 입력, 단일 응답 (동기)
response = llm.invoke("삼성전자 주가에 영향을 주는 요인은?")
print(response.content)
# Out:
# 삼성전자의 주가에 영향을 주는 요인은 여러 가지가 있습니다. 주요 요인은 다음과 같습니다:
#
# 1. **재무 성과**: 삼성전자의 분기 및 연간 실적 보고서(매출, 이익 등)는 주가에 큰 영향을 미칩니다. 강한 실적 발표는 주가 상승을 유도할 수 있습니다.
#
# 2. **산업 동향**: 반도체, 스마트폰, 전자제품 등의 관련 산업 동향과 경쟁업체의 성과도 주가에 영향을 미칩니다. 예를 들어, 반도체 가격 상승, 새로운 기술 혁신 등이 긍정적인 신호로 작용할 수 있습니다.
#
# 3. **글로벌 경제 현황**: 세계 경제의 성장 둔화, 금리 인상, 환율 변동 등은 삼성전자의 수익성에 영향을 미칠 수 있습니다. 또한, 주요 시장인 미국, 중국 등에서의 경제 상황도 중요합니다.
#
# 4. **정치적 요인**: 무역 정책, 규제 변화, 지정학적 긴장 등이 삼성전자의 수출 및 운영에 영향을 미칠 수 있습니다.
#
# 5. **투자자 심리**: 시장 전반의 투자 심리와 매크로 경제 데이터(실업률, 소비자신뢰지수 등)는 주가에 간접적으로 영향을 줍니다.
#
# 6. **신제품 출시**: 삼성전자의 신제품 출시 일정이나 혁신적인 기술 발표는 소비자와 투자자의 관심을 끌어 주가에 긍정적인 영향을 줄 수 있습니다.
#
# 7. **배당 정책**: 자사주 매입이나 배당금 지급 정책은 투자자들에게 긍정적인 신호로 작용할 수 있으며, 이는 주가에 긍정적인 영향을 미칠 수 있습니다.
#
# 8. **ESG 요인**: 기업의 환경, 사회, 지배구조(ESG) 관련 성과가 중요한 평가 요소로 떠오르고 있으며, 이러한 부분이 긍정적으로 평가받으면 주가에 긍정적인 영향을 줄 수 있습니다.
#
# 이러한 다양한 요인들이 복합적으로 작용하여 삼성전자의 주가를 결정하게 됩니다.

# %%
responses[1]
# Out:
# AIMessage(content='코스피(KOSPI, Korea Composite Stock Price Index) 지수는 한국증권거래소에 상장된 모든 종목의 주가를 기준으로 산출되는 주가 종합 지수입니다. 코스피는 한국의 대표적인 주식 시장 지수로, 국내 주식 시장의 전체적인 성과를 나타내며, 경제의 상황을 파악하는 데 중요한 지표로 활용됩니다.\n\n코스피 지수의 기초는 1980년 1월 4일의 주가를 기준으로 100포인트로 설정되어 있으며, 이후 상장된 기업들의 주가 변동에 따라 지수도 변동합니다. 이 지수는 시가총액 가중 방식으로 계산되므로, 대형주가 작은 주식보다 지수에 더 큰 영향을 미칩니다.\n\n따라서 코스피 지수를 통해 투자자들은 한국 주식 시장의 전체적인 흐름과 경제적 동향을 이해할 수 있으며, 주식 투자 결정을 내리는 데 중요한 참고 자료로 사용됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 224, 'prompt_tokens': 16, 'total_tokens': 240, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_48d918fb56', 'id': 'chatcmpl-DSCEMcvStz7eJPIhzrw2X3BbiiZtz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6ac1-b316-7c22-8c56-14e081251ccd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 224, 'total_tokens': 240, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
for r in responses:
    print('*'*20) 
    print(r.content)
# Out:
# ********************
# 삼성전자 주가에 영향을 주는 요인은 여러 가지가 있습니다. 주요 요인은 다음과 같습니다:
#
# 1. **경제 지표**: 국내외 경제 성장률, 실업률, 소비자 신뢰 지수 등의 경제 지표가 삼성전자의 실적에 영향을 미칩니다.
#
# 2. **반도체 시장 동향**: 삼성전자는 반도체 산업에서 큰 비중을 차지하고 있으므로, 메모리 칩 및 반도체 가격, 수급 상황 등은 직접적인 영향을 미칩니다.
#
# 3. **제품 출시 및 혁신**: 새로운 제품의 출시, 기술 혁신, 품질 개선 등이 소비자 수요에 영향을 미쳐 매출 및 이익에 변화를 줄 수 있습니다.
#
# 4. **경쟁사 동향**: 애플, 화웨이, 샤오미 등 주요 경쟁사의 움직임과 제품 출시, 시장 점유율 변동도 삼성전자의 시장 경쟁력에 영향을 미칩니다.
#
# 5. **환율 변동**: 삼성전자와 같은 다국적 기업은 환율 변동에 민감하게 반응하며, 원화 강세나 약세에 따라 수익성에 영향을 받을 수 있습니다.
#
# 6. **정치적 및 규제 환경**: 특정 국가의 무역 정책, 규제 변화, 정치적 불안정 등도 삼성전자의 글로벌 운영에 영향을 미칠 수 있습니다.
#
# 7. **주요 뉴스 및 사건**: 기업 관련 뉴스, 재무 보고서 및 실적 발표, 인수합병 등의 사건도 투자자들의 심리에 영향을 미쳐 주가에 변동을 줄 수 있습니다.
#
# 8. **시장 심리**: 전체 주식 시장의 분위기나 투자자 심리도 삼성전자 주가에 영향을 미칠 수 있습니다. 긍정적인 뉴스가 많을 경우 주가가 상승할 수 있고, 부정적인 뉴스가 많을 경우 하락할 수 있습니다.
#
# 이러한 요인들은 서로 연관되어 복합적으로 작용할 수 있으며, 주가의 변동성에 크게 기여합니다.
# ********************
# 코스피(KOSPI, Korea Composite Stock Price Index) 지수는 한국증권거래소에 상장된 모든 종목의 주가를 기준으로 산출되는 주가 종합 지수입니다. 코스피는 한국의 대표적인 주식 시장 지수로, 국내 주식 시장의 전체적인 성과를 나타내며, 경제의 상황을 파악하는 데 중요한 지표로 활용됩니다.
#
# 코스피 지수의 기초는 1980년 1월 4일의 주가를 기준으로 100포인트로 설정되어 있으며, 이후 상장된 기업들의 주가 변동에 따라 지수도 변동합니다. 이 지수는 시가총액 가중 방식으로 계산되므로, 대형주가 작은 주식보다 지수에 더 큰 영향을 미칩니다.
#
# 따라서 코스피 지수를 통해 투자자들은 한국 주식 시장의 전체적인 흐름과 경제적 동향을 이해할 수 있으며, 주식 투자 결정을 내리는 데 중요한 참고 자료로 사용됩니다.
# ********************
# ETF(Exchange-Traded Fund)와 펀드는 투자자들이 자금을 모아 다양한 자산에 투자하는 방식이지만, 몇 가지 중요한 차이점이 있습니다.
#
# 1. **거래 방식**:
#    - **ETF**: 주식처럼 거래소에서 실시간으로 매매할 수 있습니다. 투자자는 주식 시장이 열려 있는 동안 언제든지 가격에 따라 ETF를 사고팔 수 있습니다.
#    - **펀드**: 일반적으로 하루에 한 번, 장 마감 후에만 가격이 책정되어 거래됩니다. 투자자가 매수 또는 매도를 요청하면, 해당 요청은 다음 거래일에 처리됩니다.
#
# 2. **운영 방식**:
#    - **ETF**: 일반적으로 특정 인덱스를 추적하도록 설계된 기초 자산의 집합입니다. 이러한 자산들은 보통 상장된 주식, 채권, 상품 등이 포함됩니다.
#    - **펀드**: 액티브(능동적) 또는 패시브(수동적) 방식으로 운영될 수 있으며, 펀드 매니저가 자산을 관리합니다. 액티브 펀드는 특정 목표 수익률을 넘기기 위해 적극적으로 매매를 하며, 패시브 펀드는 특정 지수를 추적합니다.
#
# 3. **비용 구조**:
#    - **ETF**: 일반적으로 낮은 관리 수수료를 가진 경우가 많으며, 거래 시 증권사 수수료가 발생할 수 있습니다.
#    - **펀드**: 관리 수수료와 기타 추가 비용이 발생할 수 있으며, 특히 액티브 펀드는 수수료가 더 높은 경우가 많습니다.
#
# 4. **세금 효율성**:
#    - **ETF**: 일반적으로 세금 측면에서 더 효율적입니다. 자산 매매 시 필요한 세금이 줄어들 수 있습니다.
#    - **펀드**: 투자자가 수익을 실현할 때마다 세금이 발생할 수 있습니다.
#
# 정리하자면, ETF는 주식처럼 거래되고 낮은 비용을 가진 관리형 상품인 반면, 펀드는 보통 액티브 매니지먼트에 의해 운영되며 거래 방식이 다릅니다. 선택은 개인의 투자 목적과 성향에 따라 달라질 수 있습니다.

# %%
# batch() - 여러 입력을 한 번에 처리 (동기)
# 중복 토큰을 줄여 묶어 처리 → 비용 절감 효과
questions = [
    "삼성전자 주가에 영향을 주는 요인은?",
    "코스피 지수란 무엇인가?",
    "ETF와 펀드의 차이는?"
]
responses = llm.batch(questions)
for r in responses:
    print(r.content)
    print()
# Out:
# 삼성전자 주가에 영향을 주는 요인은 여러 가지가 있습니다. 주요 요인은 다음과 같습니다:
#
# 1. **경제 지표**: 국내외 경제 성장률, 실업률, 소비자 신뢰 지수 등의 경제 지표가 삼성전자의 실적에 영향을 미칩니다.
#
# 2. **반도체 시장 동향**: 삼성전자는 반도체 산업에서 큰 비중을 차지하고 있으므로, 메모리 칩 및 반도체 가격, 수급 상황 등은 직접적인 영향을 미칩니다.
#
# 3. **제품 출시 및 혁신**: 새로운 제품의 출시, 기술 혁신, 품질 개선 등이 소비자 수요에 영향을 미쳐 매출 및 이익에 변화를 줄 수 있습니다.
#
# 4. **경쟁사 동향**: 애플, 화웨이, 샤오미 등 주요 경쟁사의 움직임과 제품 출시, 시장 점유율 변동도 삼성전자의 시장 경쟁력에 영향을 미칩니다.
#
# 5. **환율 변동**: 삼성전자와 같은 다국적 기업은 환율 변동에 민감하게 반응하며, 원화 강세나 약세에 따라 수익성에 영향을 받을 수 있습니다.
#
# 6. **정치적 및 규제 환경**: 특정 국가의 무역 정책, 규제 변화, 정치적 불안정 등도 삼성전자의 글로벌 운영에 영향을 미칠 수 있습니다.
#
# 7. **주요 뉴스 및 사건**: 기업 관련 뉴스, 재무 보고서 및 실적 발표, 인수합병 등의 사건도 투자자들의 심리에 영향을 미쳐 주가에 변동을 줄 수 있습니다.
#
# 8. **시장 심리**: 전체 주식 시장의 분위기나 투자자 심리도 삼성전자 주가에 영향을 미칠 수 있습니다. 긍정적인 뉴스가 많을 경우 주가가 상승할 수 있고, 부정적인 뉴스가 많을 경우 하락할 수 있습니다.
#
# 이러한 요인들은 서로 연관되어 복합적으로 작용할 수 있으며, 주가의 변동성에 크게 기여합니다.
#
# 코스피(KOSPI, Korea Composite Stock Price Index) 지수는 한국증권거래소에 상장된 모든 종목의 주가를 기준으로 산출되는 주가 종합 지수입니다. 코스피는 한국의 대표적인 주식 시장 지수로, 국내 주식 시장의 전체적인 성과를 나타내며, 경제의 상황을 파악하는 데 중요한 지표로 활용됩니다.
#
# 코스피 지수의 기초는 1980년 1월 4일의 주가를 기준으로 100포인트로 설정되어 있으며, 이후 상장된 기업들의 주가 변동에 따라 지수도 변동합니다. 이 지수는 시가총액 가중 방식으로 계산되므로, 대형주가 작은 주식보다 지수에 더 큰 영향을 미칩니다.
#
# 따라서 코스피 지수를 통해 투자자들은 한국 주식 시장의 전체적인 흐름과 경제적 동향을 이해할 수 있으며, 주식 투자 결정을 내리는 데 중요한 참고 자료로 사용됩니다.
#
# ETF(Exchange-Traded Fund)와 펀드는 투자자들이 자금을 모아 다양한 자산에 투자하는 방식이지만, 몇 가지 중요한 차이점이 있습니다.
#
# 1. **거래 방식**:
#    - **ETF**: 주식처럼 거래소에서 실시간으로 매매할 수 있습니다. 투자자는 주식 시장이 열려 있는 동안 언제든지 가격에 따라 ETF를 사고팔 수 있습니다.
#    - **펀드**: 일반적으로 하루에 한 번, 장 마감 후에만 가격이 책정되어 거래됩니다. 투자자가 매수 또는 매도를 요청하면, 해당 요청은 다음 거래일에 처리됩니다.
#
# 2. **운영 방식**:
#    - **ETF**: 일반적으로 특정 인덱스를 추적하도록 설계된 기초 자산의 집합입니다. 이러한 자산들은 보통 상장된 주식, 채권, 상품 등이 포함됩니다.
#    - **펀드**: 액티브(능동적) 또는 패시브(수동적) 방식으로 운영될 수 있으며, 펀드 매니저가 자산을 관리합니다. 액티브 펀드는 특정 목표 수익률을 넘기기 위해 적극적으로 매매를 하며, 패시브 펀드는 특정 지수를 추적합니다.
#
# 3. **비용 구조**:
#    - **ETF**: 일반적으로 낮은 관리 수수료를 가진 경우가 많으며, 거래 시 증권사 수수료가 발생할 수 있습니다.
#    - **펀드**: 관리 수수료와 기타 추가 비용이 발생할 수 있으며, 특히 액티브 펀드는 수수료가 더 높은 경우가 많습니다.
#
# 4. **세금 효율성**:
#    - **ETF**: 일반적으로 세금 측면에서 더 효율적입니다. 자산 매매 시 필요한 세금이 줄어들 수 있습니다.
#    - **펀드**: 투자자가 수익을 실현할 때마다 세금이 발생할 수 있습니다.
#
# 정리하자면, ETF는 주식처럼 거래되고 낮은 비용을 가진 관리형 상품인 반면, 펀드는 보통 액티브 매니지먼트에 의해 운영되며 거래 방식이 다릅니다. 선택은 개인의 투자 목적과 성향에 따라 달라질 수 있습니다.

# %%
messages = [
    [("system", "당신은 서울의 음식 전문가입니다."), ("human", "서울 광장시장에서 먹을 만한 길거리 음식들을 소개해 주세요")],
    [("system", "당신은 서울의 문화 전문가입니다."), ("human", "서울에서 데이트할 때 가 볼 만한 분위기 좋은 곳들을 알려 주세요")] 
]

# %%
# stream() - 실시간 스트리밍 출력 (토큰 단위로 출력)
for chunk in llm.stream("환율이 수출 기업에 미치는 영향은?"):
    print(chunk.content, end="**", flush=True)
# Out:
# **환**율**은** 수**출** 기업**에** 여러** 가지** 방식**으로** 영향을** 미**칠** 수** 있습니다**.** 주요** 영향** 요소**는** 다음**과** 같습니다**:
#
# **1**.** ****가격** 경쟁**력******:** 환**율**이** 하**락**(**자**국** 통**화**가** 약**세**)**하면** 수**출** 제품**의** 가격**이** 외**국** 시장**에서** 상대**적으로** 낮**아**지**기** 때문에** 가격** 경쟁**력이** 높**아**져** 수**출**이** 증가**할** 수** 있습니다**.** 반**대로**,** 환**율**이** 상승**(**자**국** 통**화**가** 강**세**)**하면** 수**출** 제품**의** 가격**이** 비**싸**져** 경쟁**력이** 감소**할** 수** 있습니다**.
#
# **2**.** ****매**출** 및** 수**익******:** 환**율** 변**동**은** 외**환** 수**익**에** 직접**적인** 영향을** 미**칩니다**.** 수**출** 기업**이** 외**화**로** 매**출**을** 올**릴** 경우**,** 환**율**이** 유**리**한** 방향**으로** 움직**이면** 매**출**이** 증가**할** 수** 있지만**,** 불**리**한** 방향**으로** 변**동**하면** 수**익**이** 줄**어**들** 수** 있습니다**.
#
# **3**.** ****해**외** 시장** 접근******:** 환**율**의** 변**동**성**은** 해외** 시장** 접근**성**에도** 영향을** 미**칠** 수** 있습니다**.** 환**율**이** 불**안**정**할** 경우** 수**출** 기업**은** 장**기** 계약**을** 체**결**하기** 어려**워**지고**,** 이는** 수**출** 성장**에** 부**정**적인** 영향을** 미**칠** 수** 있습니다**.
#
# **4**.** ****원**자**재** 가격******:** 많은** 수**출** 기업**이** 외**국**에서** 원**자**재**를** 구매**합니다**.** 환**율** 변화**는** 원**자**재** 가격**에도** 영향을** 미**칠** 수** 있으며**,** 이는** 생산** 비용**에** 따라** 수**출** 가격**에** 영향을** 줄** 수** 있습니다**.
#
# **5**.** ****리**스크** 관리******:** 환**율** 변**동**에** 따른** 리**스크**를** 관리**하기** 위해** 많은** 수**출** 기업**이** 헤**징**(**환**리**스크** 관리** 전략**)을** 사용**합니다**.** 이는** 추가**적인** 비용**을** 발생**시**킬** 수** 있지만**,** 환**율**의** 급**격**한** 변**동**으로**부터** 보호**받**는** 데** 도움**을** 줄** 수** 있습니다**.
#
# **6**.** ****수**출** 전략** 조**정******:** 환**율**의** 변**동**에** 따라** 기업**은** 수**출** 전략**을** 조**정**해야** 할** 수도** 있습니다**.** 예**를** 들어**,** 특정** 국가**에** 대한** 수**출**을** 늘**리**거나** 줄**이는** 등의** 결정**이** 필요**할** 수** 있습니다**.
#
# **결**론**적으로**,** 환**율**은** 수**출** 기업**에** 매우** 중요한** 요소**로** 작**용**하며**,** 지속**적인** 모**니**터**링**과** 전략**적인** 대응**이** 필요**합니다**.********

# %% [markdown]
# # 비동기 vs 동기 처리

# %%
questions = [f"주식 투자 팁 {i}번째" for i in range(10)]
questions
# Out:
# ['주식 투자 팁 0번째',
#  '주식 투자 팁 1번째',
#  '주식 투자 팁 2번째',
#  '주식 투자 팁 3번째',
#  '주식 투자 팁 4번째',
#  '주식 투자 팁 5번째',
#  '주식 투자 팁 6번째',
#  '주식 투자 팁 7번째',
#  '주식 투자 팁 8번째',
#  '주식 투자 팁 9번째']

# %%
import asyncio
import time
from langchain_openai import ChatOpenAI
#llm = ChatOpenAI(model="gpt-4o-mini")

# 비동기 병렬 처리
async def invoke_async(question): #각 프롬프트 1개 처리
    response = await llm.ainvoke(question)
    return response.content

async def invoke_parallel(questions): #다수의 프롬프트 목록을 처리
    tasks = [invoke_async(q) for q in questions]
    return await asyncio.gather(*tasks)

# %%
res = await invoke_async(questions[0])
#print(res)

# %%
# 비동기 실행 시간 측정
start = time.perf_counter()
results = await invoke_parallel(questions)
end = time.perf_counter()
print(f"비동기 처리: {end - start:.2f}초")   # 약 5~6초 > 8.6초
# Out:
# 비동기 처리: 8.64초

# %%
results
#주식 투자 팁 1번째
# Out:
# ['주식 투자에 대한 0번째 팁, 즉 가장 기본적인 팁은 다음과 같습니다:\n\n**기초 지식 습득하기**: 주식 시장의 작동 방식, 기업 재무제표, 경제 지표, 기술적 분석과 같은 기본 개념들을 충분히 이해하는 것이 중요합니다. 주식 투자는 복잡한 활동일 수 있으므로, 충분한 기초 지식이 없이 시작하는 것은 위험할 수 있습니다. 관련 서적을 읽거나 온라인 강의를 듣는 것부터 시작해보세요.\n\n이후에는 자신의 투자 목표와 성향을 잘 파악하고, 적절한 전략을 세우는 것이 중요합니다.',
#  '주식 투자에서 가장 중요한 팁 중 하나는 **철저한 조사와 분석**입니다. 주식을 사기 전에 해당 기업에 대한 충분한 정보와 데이터를 수집하는 것이 필수적입니다. 다음은 이를 위한 몇 가지 접근 방법입니다:\n\n1. **재무 제표 분석**: 기업의 손익계산서, 대차대조표, 현금 흐름 표를 통해 재무 건강을 평가하세요.\n2. **산업 및 경쟁 분석**: 해당 기업이 속한 산업의 트렌드와 경쟁사를 분석하여 그 기업의 위치와 성장 가능성을 파악하세요.\n3. **뉴스 및 소셜 미디어 모니터링**: 최근 뉴스와 소셜 미디어에서의 여론을 확인하여 시장의 동향을 파악하세요.\n\n이런 방식으로 기업에 대한 이해를 높이고, 투자 결정을 하는 데 필요한 정보를 갖춘다면 보다 나은 성과를 기대할 수 있습니다.',
#  '주식 투자에 대한 두 번째 팁은 **리서치와 분석의 중요성**입니다. 주식을 구매하기 전에 해당 회사와 업종에 대한 충분한 정보를 수집하고 분석하는 것이 필수적입니다. 이를 위해 다음과 같은 방법을 활용할 수 있습니다:\n\n1. **재무제표 분석**: 기업의 재무제표를 통해 수익성, 부채 수준, 현금 흐름 등을 확인하고, 기업의 재무 건전성을 평가합니다.\n\n2. **산업 동향 파악**: 투자하고자 하는 기업이 속한 산업의 변화와 트렌드를 파악하여 해당 기업의 성장 가능성을 예측합니다.\n\n3. **경쟁사 비교**: 동종 업계의 다른 기업들과 비교하여 상대적인 강점과 약점을 분석합니다. 이를 통해 투자 결정을 보다 잘 내릴 수 있습니다.\n\n4. **뉴스와 이슈 체크**: 기업에 영향을 미칠 수 있는 뉴스, 정책 변화, 경제 지표 등을 지속적으로 체크하여 시장의 흐름을 이해합니다.\n\n5. **전문가 의견**: 애널리스트의 보고서나 투자 전문가의 의견도 고려하여 다양한 관점을 포함한 의사 결정을 할 수 있습니다.\n\n철저한 리서치는 투자 성공의 기초를 마련해 주며, 단순한 감이나 추측보다는 데이터 기반의 접근이 더 많은 이익을 가져올 수 있습니다.',
#  '주식 투자에 대한 세 번째 팁은 **다각화**입니다. \n\n다각화는 포트폴리오를 여러 종목이나 자산으로 나누어 투자하는 전략입니다. 이를 통해 특정 주식이나 산업의 변동성이 포트폴리오 전체에 미치는 영향을 줄일 수 있습니다. 예를 들어, 한 산업이나 기업의 주가가 하락하더라도 다른 산업의 주식이나 자산이 반등하면 손실을 상쇄할 수 있습니다.\n\n다각화를 할 때는 서로 다른 산업, 지역, 자산군(주식, 채권, 부동산 등)에 투자하는 것이 좋습니다. 이렇게 하면 시장의 변화에 대한 영향을 최소화할 수 있어 안정적인 수익을 기대할 수 있습니다.\n\n다각화는 투자 위험을 줄이는 유용한 방법이지만, 과도한 다각화는 관리의 비효율성을 초래할 수 있으므로 신중하게 접근하는 것이 중요합니다.',
#  '주식 투자에 대한 네 번째 팁은 **다양한 포트폴리오 구축**입니다. \n\n### 다양한 포트폴리오 구축\n1. **자산 분산:** 여러 산업과 지역에 걸쳐 다양한 주식을 보유하여 리스크를 분산시킵니다. 특정 주식이나 산업에 과도하게 의존하면 예상치 못한 손실에 취약해질 수 있습니다.\n\n2. **주식 뿐만 아니라 다른 자산 클래스 포함:** 주식 외에도 채권, 부동산, 대체 투자(예: 원자재 등) 등을 포함한 다각화 포트폴리오를 구축하는 것이 좋습니다. 이는 경제 변화에 대한 저항력을 높이는 데 도움을 줄 수 있습니다.\n\n3. **정기적인 재조정:** 시장 변동성에 따라 주식의 비중이 달라질 수 있으므로, 정기적으로 포트폴리오를 점검하고 필요에 따라 재조정하는 것이 중요합니다. \n\n4. **리스크 tolerance 고려:** 자신의 투자 성향과 리스크 감수 능력을 고려하여 포트폴리오를 구성하세요. 자신의 투자 목표와 시간적 여유에 맞춰 리스크와 수익률을 조정해야 합니다.\n\n이런 방식으로 다양한 포트폴리오를 구성하면, 불확실성에 대비하고 보다 안정적인 수익을 추구할 수 있습니다.',
#  '주식 투자에 관한 다섯 번째 팁은 "장기적인 관점 유지하기"입니다.\n\n주식 시장은 단기적으로 변동성이 크고 예측하기 어려운 경우가 많습니다. 따라서, 단기적인 가격 변동에 일희일비하기보다는 장기적인 목표와 투자 전략을 세우고 그에 따라 투자하는 것이 중요합니다. \n\n장기 투자는 일반적으로 감정적인 결정을 줄이고, 복리 효과를 극대화하며, 시간에 따른 기업 성장 가능성을 더 효과적으로 반영할 수 있습니다. 따라서, 투자하기 전에 기업의 기본적 가치와 성장 가능성을 분석하고, 이를 바탕으로 장기적인 시각으로 접근하는 것이 좋습니다. \n\n장기적인 투자 관점을 유지하면 시장의 일시적인 하락에도 더 잘 대처할 수 있으며, 꾸준한 성과를 기대할 수 있습니다.',
#  '주식 투자 팁 여섯 번째는 **리스크 관리를 철저히 하라**입니다. \n\n투자에서 리스크를 완전히 피할 수는 없지만, 효과적인 리스크 관리 전략을 통해 손실을 최소화할 수 있습니다. 다음은 리스크 관리를 위한 몇 가지 방법입니다:\n\n1. **분산 투자**: 다양한 산업 및 자산 클래스에 투자하여 특정 자산의 변동성이 전체 포트폴리오에 미치는 영향을 줄입니다.\n\n2. **손절매 설정**: 특정 가격 이하로 주가가 떨어지면 자동으로 매도하도록 설정하여 큰 손실을 방지합니다.\n\n3. **자산 비중 조절**: 투자 자산의 비중을 지속적으로 조정하여 리스크를 관리합니다. 예를 들어, 시장 상황에 따라 주식보다 채권 비중을 늘리는 방법이 있습니다.\n\n4. **정기적인 포트폴리오 점검**: 정기적으로 투자 성과를 점검하고 시장의 변화에 따라 포트폴리오를 조정합니다.\n\n5. **적절한 투자 기간 설정**: 단기 투자보다는 장기 투자를 통해 시장 변동성에 대한 리스크를 줄이고 안정적인 수익을 추구합니다.\n\n6. **정보 분석**: 충분한 분석과 연구를 통해 각 투자에 대한 이해를 높이고, 감정적인 결정을 피하는 것이 중요합니다.\n\n이와 같은 리스크 관리 전략을 통해 안정적이고 지속적인 투자를 할 수 있습니다.',
#  '주식 투자에 관한 7번째 팁은 "상황에 맞는 포트폴리오 다각화"입니다. \n\n다각화는 투자 리스크를 줄이는 데 매우 중요한 전략입니다. 다양한 산업과 자산군에 투자하면 특정 주식이나 sector의 변동성이 전체 포트폴리오에 미치는 영향을 최소화할 수 있습니다. \n\n다음은 포트폴리오 다각화에 대한 몇 가지 방법입니다:\n\n1. **산업 분산:** 서로 다른 산업에 투자하여 특정 산업의 영향에서 벗어나도록 합니다. 예를 들어, 기술, 헬스케어, 금융, 소비재 등 다양한 분야에 투자하세요.\n\n2. **자산군 분산:** 주식뿐만 아니라 채권, 부동산 투자 신탁(REITs), 상품 등 다양한 자산군에 투자하여 위험을 분산합니다.\n\n3. **국가 및 지역 분산:** 국내 주식뿐만 아니라 해외 주식에도 투자하여 국가별 위험에 대한 노출을 줄입니다.\n\n4. **유형 자산:** 금이나 은과 같은 귀금속, 또는 부동산과 같은 실물 자산에 투자하여 인플레이션 헷지를 고려할 수 있습니다.\n\n5. **투자 스타일:** 가치주, 성장주, 배당주 등 서로 다른 투자 스타일을 결합하여 시장 상황에 맞춰 대응합니다.\n\n각 자산의 성과 및 시장 변동성을 주의 깊게 모니터링하며, 정기적으로 포트폴리오를 재조정하는 것도 잊지 마세요. 다각화는 리스크 관리의 중요한 요소이지만, 모든 투자에 위험이 따른다는 점을 항상 기억해야 합니다.',
#  '주식 투자에 대한 8번째 팁은 "꾸준한 학습과 시장 모니터링"입니다. 주식 시장은 변화가 빠르고, 다양한 경제적 요인, 정책, 기술 발전 등이 주가에 영향을 미칠 수 있습니다. 따라서 지속적으로 학습하고 정보를 업데이트하는 것이 중요합니다. \n\n1. **뉴스와 경제 지표 체크**: 경제 뉴스, 기업 실적 발표, 금리 변화 등의 정보를 지속적으로 확인하세요.\n2. **투자 서적과 자료 활용**: 주식 투자에 관한 다양한 서적, 블로그, 유튜브 채널 등을 통해 지식을 쌓는 것이 좋습니다.\n3. **세미나 및 웨비나 참석**: 전문가의 강의를 듣고 최신 투자 트렌드와 전략에 대해 배워보세요.\n\n꾸준한 학습은 투자 결정을 내리는 데 큰 도움이 될 것입니다.',
#  '주식 투자에서 중요한 팁 중 아홉 번째는 **분산 투자**입니다. 단일 주식이나 특정 섹터의 주식에 모든 자금을 투자하는 대신, 다양한 기업과 산업에 걸쳐 자산을 분산시키는 것이 중요합니다. 이를 통해 리스크를 줄이고, 특정 주식이나 시장의 변동성에 대한 영향을 최소화할 수 있습니다.\n\n분산 투자 시 고려할 점은 다음과 같습니다:\n\n1. **산업 다각화**: 다양한 산업 섹터에 투자해 특정 산업의 부진이 전체 포트폴리오에 미치는 영향을 줄입니다.\n2. **지역 다각화**: 국내뿐 아니라 해외 시장에도 투자하여 지역별 경제 상황에 따른 리스크를 분산합니다.\n3. **자산 클래스 다각화**: 주식 외에도 채권, 부동산, 원자재 등 다양한 자산 클래스에 투자하여 리스크를 분산합니다.\n4. **투자 스타일 다각화**: 가치주, 성장주, 배당주 등 다양한 스타일의 주식에 투자함으로써 시장의 다양한 상황에 대응할 수 있습니다.\n\n이러한 분산 전략을 통해 투자 포트폴리오의 안정성을 높이고, 장기적으로 더 나은 투자 성과를 기대할 수 있습니다.']

# %%
for index, content in enumerate(results):
    print(f"{index}, content:{content}")
# Out:
# 0, content:주식 투자에 대한 0번째 팁, 즉 가장 기본적인 팁은 다음과 같습니다:
#
# **기초 지식 습득하기**: 주식 시장의 작동 방식, 기업 재무제표, 경제 지표, 기술적 분석과 같은 기본 개념들을 충분히 이해하는 것이 중요합니다. 주식 투자는 복잡한 활동일 수 있으므로, 충분한 기초 지식이 없이 시작하는 것은 위험할 수 있습니다. 관련 서적을 읽거나 온라인 강의를 듣는 것부터 시작해보세요.
#
# 이후에는 자신의 투자 목표와 성향을 잘 파악하고, 적절한 전략을 세우는 것이 중요합니다.
# 1, content:주식 투자에서 가장 중요한 팁 중 하나는 **철저한 조사와 분석**입니다. 주식을 사기 전에 해당 기업에 대한 충분한 정보와 데이터를 수집하는 것이 필수적입니다. 다음은 이를 위한 몇 가지 접근 방법입니다:
#
# 1. **재무 제표 분석**: 기업의 손익계산서, 대차대조표, 현금 흐름 표를 통해 재무 건강을 평가하세요.
# 2. **산업 및 경쟁 분석**: 해당 기업이 속한 산업의 트렌드와 경쟁사를 분석하여 그 기업의 위치와 성장 가능성을 파악하세요.
# 3. **뉴스 및 소셜 미디어 모니터링**: 최근 뉴스와 소셜 미디어에서의 여론을 확인하여 시장의 동향을 파악하세요.
#
# 이런 방식으로 기업에 대한 이해를 높이고, 투자 결정을 하는 데 필요한 정보를 갖춘다면 보다 나은 성과를 기대할 수 있습니다.
# 2, content:주식 투자에 대한 두 번째 팁은 **리서치와 분석의 중요성**입니다. 주식을 구매하기 전에 해당 회사와 업종에 대한 충분한 정보를 수집하고 분석하는 것이 필수적입니다. 이를 위해 다음과 같은 방법을 활용할 수 있습니다:
#
# 1. **재무제표 분석**: 기업의 재무제표를 통해 수익성, 부채 수준, 현금 흐름 등을 확인하고, 기업의 재무 건전성을 평가합니다.
#
# 2. **산업 동향 파악**: 투자하고자 하는 기업이 속한 산업의 변화와 트렌드를 파악하여 해당 기업의 성장 가능성을 예측합니다.
#
# 3. **경쟁사 비교**: 동종 업계의 다른 기업들과 비교하여 상대적인 강점과 약점을 분석합니다. 이를 통해 투자 결정을 보다 잘 내릴 수 있습니다.
#
# 4. **뉴스와 이슈 체크**: 기업에 영향을 미칠 수 있는 뉴스, 정책 변화, 경제 지표 등을 지속적으로 체크하여 시장의 흐름을 이해합니다.
#
# 5. **전문가 의견**: 애널리스트의 보고서나 투자 전문가의 의견도 고려하여 다양한 관점을 포함한 의사 결정을 할 수 있습니다.
#
# 철저한 리서치는 투자 성공의 기초를 마련해 주며, 단순한 감이나 추측보다는 데이터 기반의 접근이 더 많은 이익을 가져올 수 있습니다.
# 3, content:주식 투자에 대한 세 번째 팁은 **다각화**입니다.
#
# 다각화는 포트폴리오를 여러 종목이나 자산으로 나누어 투자하는 전략입니다. 이를 통해 특정 주식이나 산업의 변동성이 포트폴리오 전체에 미치는 영향을 줄일 수 있습니다. 예를 들어, 한 산업이나 기업의 주가가 하락하더라도 다른 산업의 주식이나 자산이 반등하면 손실을 상쇄할 수 있습니다.
#
# 다각화를 할 때는 서로 다른 산업, 지역, 자산군(주식, 채권, 부동산 등)에 투자하는 것이 좋습니다. 이렇게 하면 시장의 변화에 대한 영향을 최소화할 수 있어 안정적인 수익을 기대할 수 있습니다.
#
# 다각화는 투자 위험을 줄이는 유용한 방법이지만, 과도한 다각화는 관리의 비효율성을 초래할 수 있으므로 신중하게 접근하는 것이 중요합니다.
# 4, content:주식 투자에 대한 네 번째 팁은 **다양한 포트폴리오 구축**입니다.
#
# ### 다양한 포트폴리오 구축
# 1. **자산 분산:** 여러 산업과 지역에 걸쳐 다양한 주식을 보유하여 리스크를 분산시킵니다. 특정 주식이나 산업에 과도하게 의존하면 예상치 못한 손실에 취약해질 수 있습니다.
#
# 2. **주식 뿐만 아니라 다른 자산 클래스 포함:** 주식 외에도 채권, 부동산, 대체 투자(예: 원자재 등) 등을 포함한 다각화 포트폴리오를 구축하는 것이 좋습니다. 이는 경제 변화에 대한 저항력을 높이는 데 도움을 줄 수 있습니다.
#
# 3. **정기적인 재조정:** 시장 변동성에 따라 주식의 비중이 달라질 수 있으므로, 정기적으로 포트폴리오를 점검하고 필요에 따라 재조정하는 것이 중요합니다.
#
# 4. **리스크 tolerance 고려:** 자신의 투자 성향과 리스크 감수 능력을 고려하여 포트폴리오를 구성하세요. 자신의 투자 목표와 시간적 여유에 맞춰 리스크와 수익률을 조정해야 합니다.
#
# 이런 방식으로 다양한 포트폴리오를 구성하면, 불확실성에 대비하고 보다 안정적인 수익을 추구할 수 있습니다.
# 5, content:주식 투자에 관한 다섯 번째 팁은 "장기적인 관점 유지하기"입니다.
#
# 주식 시장은 단기적으로 변동성이 크고 예측하기 어려운 경우가 많습니다. 따라서, 단기적인 가격 변동에 일희일비하기보다는 장기적인 목표와 투자 전략을 세우고 그에 따라 투자하는 것이 중요합니다.
#
# 장기 투자는 일반적으로 감정적인 결정을 줄이고, 복리 효과를 극대화하며, 시간에 따른 기업 성장 가능성을 더 효과적으로 반영할 수 있습니다. 따라서, 투자하기 전에 기업의 기본적 가치와 성장 가능성을 분석하고, 이를 바탕으로 장기적인 시각으로 접근하는 것이 좋습니다.
#
# 장기적인 투자 관점을 유지하면 시장의 일시적인 하락에도 더 잘 대처할 수 있으며, 꾸준한 성과를 기대할 수 있습니다.
# 6, content:주식 투자 팁 여섯 번째는 **리스크 관리를 철저히 하라**입니다.
#
# 투자에서 리스크를 완전히 피할 수는 없지만, 효과적인 리스크 관리 전략을 통해 손실을 최소화할 수 있습니다. 다음은 리스크 관리를 위한 몇 가지 방법입니다:
#
# 1. **분산 투자**: 다양한 산업 및 자산 클래스에 투자하여 특정 자산의 변동성이 전체 포트폴리오에 미치는 영향을 줄입니다.
#
# 2. **손절매 설정**: 특정 가격 이하로 주가가 떨어지면 자동으로 매도하도록 설정하여 큰 손실을 방지합니다.
#
# 3. **자산 비중 조절**: 투자 자산의 비중을 지속적으로 조정하여 리스크를 관리합니다. 예를 들어, 시장 상황에 따라 주식보다 채권 비중을 늘리는 방법이 있습니다.
#
# 4. **정기적인 포트폴리오 점검**: 정기적으로 투자 성과를 점검하고 시장의 변화에 따라 포트폴리오를 조정합니다.
#
# 5. **적절한 투자 기간 설정**: 단기 투자보다는 장기 투자를 통해 시장 변동성에 대한 리스크를 줄이고 안정적인 수익을 추구합니다.
#
# 6. **정보 분석**: 충분한 분석과 연구를 통해 각 투자에 대한 이해를 높이고, 감정적인 결정을 피하는 것이 중요합니다.
#
# 이와 같은 리스크 관리 전략을 통해 안정적이고 지속적인 투자를 할 수 있습니다.
# 7, content:주식 투자에 관한 7번째 팁은 "상황에 맞는 포트폴리오 다각화"입니다.
#
# 다각화는 투자 리스크를 줄이는 데 매우 중요한 전략입니다. 다양한 산업과 자산군에 투자하면 특정 주식이나 sector의 변동성이 전체 포트폴리오에 미치는 영향을 최소화할 수 있습니다.
#
# 다음은 포트폴리오 다각화에 대한 몇 가지 방법입니다:
#
# 1. **산업 분산:** 서로 다른 산업에 투자하여 특정 산업의 영향에서 벗어나도록 합니다. 예를 들어, 기술, 헬스케어, 금융, 소비재 등 다양한 분야에 투자하세요.
#
# 2. **자산군 분산:** 주식뿐만 아니라 채권, 부동산 투자 신탁(REITs), 상품 등 다양한 자산군에 투자하여 위험을 분산합니다.
#
# 3. **국가 및 지역 분산:** 국내 주식뿐만 아니라 해외 주식에도 투자하여 국가별 위험에 대한 노출을 줄입니다.
#
# 4. **유형 자산:** 금이나 은과 같은 귀금속, 또는 부동산과 같은 실물 자산에 투자하여 인플레이션 헷지를 고려할 수 있습니다.
#
# 5. **투자 스타일:** 가치주, 성장주, 배당주 등 서로 다른 투자 스타일을 결합하여 시장 상황에 맞춰 대응합니다.
#
# 각 자산의 성과 및 시장 변동성을 주의 깊게 모니터링하며, 정기적으로 포트폴리오를 재조정하는 것도 잊지 마세요. 다각화는 리스크 관리의 중요한 요소이지만, 모든 투자에 위험이 따른다는 점을 항상 기억해야 합니다.
# 8, content:주식 투자에 대한 8번째 팁은 "꾸준한 학습과 시장 모니터링"입니다. 주식 시장은 변화가 빠르고, 다양한 경제적 요인, 정책, 기술 발전 등이 주가에 영향을 미칠 수 있습니다. 따라서 지속적으로 학습하고 정보를 업데이트하는 것이 중요합니다.
#
# 1. **뉴스와 경제 지표 체크**: 경제 뉴스, 기업 실적 발표, 금리 변화 등의 정보를 지속적으로 확인하세요.
# 2. **투자 서적과 자료 활용**: 주식 투자에 관한 다양한 서적, 블로그, 유튜브 채널 등을 통해 지식을 쌓는 것이 좋습니다.
# 3. **세미나 및 웨비나 참석**: 전문가의 강의를 듣고 최신 투자 트렌드와 전략에 대해 배워보세요.
#
# 꾸준한 학습은 투자 결정을 내리는 데 큰 도움이 될 것입니다.
# 9, content:주식 투자에서 중요한 팁 중 아홉 번째는 **분산 투자**입니다. 단일 주식이나 특정 섹터의 주식에 모든 자금을 투자하는 대신, 다양한 기업과 산업에 걸쳐 자산을 분산시키는 것이 중요합니다. 이를 통해 리스크를 줄이고, 특정 주식이나 시장의 변동성에 대한 영향을 최소화할 수 있습니다.
#
# 분산 투자 시 고려할 점은 다음과 같습니다:
#
# 1. **산업 다각화**: 다양한 산업 섹터에 투자해 특정 산업의 부진이 전체 포트폴리오에 미치는 영향을 줄입니다.
# 2. **지역 다각화**: 국내뿐 아니라 해외 시장에도 투자하여 지역별 경제 상황에 따른 리스크를 분산합니다.
# 3. **자산 클래스 다각화**: 주식 외에도 채권, 부동산, 원자재 등 다양한 자산 클래스에 투자하여 리스크를 분산합니다.
# 4. **투자 스타일 다각화**: 가치주, 성장주, 배당주 등 다양한 스타일의 주식에 투자함으로써 시장의 다양한 상황에 대응할 수 있습니다.
#
# 이러한 분산 전략을 통해 투자 포트폴리오의 안정성을 높이고, 장기적으로 더 나은 투자 성과를 기대할 수 있습니다.

# %%
# 동기 실행 시간 측정
start = time.perf_counter()
for q in questions:
    response = llm.invoke(q) #동기호출
end = time.perf_counter()
print(f"동기 처리: {end - start:.2f}초")     # 약 58초
# Out:
# 동기 처리: 58.34초

# %%
from langchain_community.callbacks import get_openai_callback
from langchain_core.messages import HumanMessage

with get_openai_callback() as callback:
    message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 길거리 음식은?")]
    response = llm.invoke(message)
    print(response.content)
    print(f"\n총 토큰: {callback.total_tokens}")
    print(f"프롬프트 토큰: {callback.prompt_tokens}")
    print(f"응답 토큰: {callback.completion_tokens}")
    print(f"비용(USD): ${callback.total_cost:.6f}")
# Out:
# 서울 광장시장에서 가장 맛있는 길거리 음식으로는 다음과 같은 것들이 있습니다:
#
# 1. **떡볶이**: 매콤한 소스에 볶아내는 떡볶이는 광장시장의 대표적인 간식입니다. 다양한 종류의 떡볶이가 있어 취향에 맞는 것을 선택할 수 있습니다.
#
# 2. **오뎅**: 따뜻한 국물에 어묵이 있는 오뎅은 겨울철에 특히 인기가 높습니다. 매콤한 소스를 추가해서 먹으면 더욱 맛있습니다.
#
# 3. **순대**: 찹쌀과 숙주, 다양한 재료로 만든 순대는 꼭 한 번 맛봐야 할 길거리 음식입니다. 간장이나 곱창과 함께 제공되기도 합니다.
#
# 4. **김밥**: 다양한 재료로 싸여 있는 김밥은 간편하게 먹기 좋은 간식입니다. 여러 종류가 있으니 취향에 맞게 선택해보세요.
#
# 5. **빈대떡**: 바삭하고 촉촉한 빈대떡은 다양한 재료와 함께 즐길 수 있어 인기가 많습니다.
#
# 6. **튀김**: 여러 가지 재료를 튀겨 만든 튀김은 바삭하고 고소한 맛으로 많은 사람들이 찾는 메뉴입니다.
#
# 이 외에도 다양한 음식을 즐길 수 있으니, 여러 가지를 시도해보는 것도 좋습니다!
#
# 총 토큰: 333
# 프롬프트 토큰: 20
# 응답 토큰: 313
# 비용(USD): $0.000191

# %%
from langchain_core.messages import SystemMessage, HumanMessage

# 대화 시작
messages = [
    SystemMessage(content="당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다."),
    HumanMessage(content="삼성전자 주식을 지금 매수해도 될까요?")
]

response = llm.invoke(messages)
#messages.append(response)  # AI 응답을 히스토리에 추가
print(response.content)
# Out:
# 삼성전자는 여러 측면에서 매력적인 투자 대상이 될 수 있습니다. 하지만 주식 매수 결정을 내리기 전에는 다음과 같은 요소를 고려해야 합니다:
#
# 1. **재무 상태**: 삼성전자의 최근 실적, 매출 성장률, 순이익 등 재무 제표를 분석하세요. 안정적인 수익성과 강력한 현금 흐름은 긍정적인 투자 신호입니다.
#
# 2. **산업 동향**: 반도체, 스마트폰, 전자기기와 같은 주요 사업 부문의 산업 동향을 살펴보세요. 글로벌 시장의 수요 변화나 기술 발전이 중요한 영향을 미칠 수 있습니다.
#
# 3. **경쟁사 분석**: 반도체 산업에서 NVIDIA, TSMC 등 경쟁사의 동향도 확인하고, 삼성전자의 시장 점유율을 비교하는 것이 유익합니다.
#
# 4. **주가 평가**: 현재 주가가 적정한지, 과거 PER(주가수익비율), PBR(주가순자산비율) 등과 비교하여 판단하세요.
#
# 5. **경제적 변수**: 글로벌 경제 및 금리 변화, 환율 변동 등이 투자에 미치는 영향을 고려해야 합니다.
#
# 6. **장기적인 전망**: 삼성전자가 주력하고 있는 기술 분야의 장기적인 전망과 회사의 미래 계획을 분석하세요.
#
# 최종적으로, 본인의 투자 목표와 리스크 수용 능력을 고려하여 결정을 내리는 것이 중요합니다. 필요하다면 전문가의 조언을 구하는 것도 좋은 방법입니다.

# %%
# 후속 질문 (이전 맥락 유지)
#messages.append(HumanMessage(content="그렇다면 목표 주가는 얼마로 보시나요?"))
messages1 = [
    SystemMessage(content="당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다."),
    HumanMessage(content="그렇다면 목표 주가는 얼마로 보시나요?")
]
response1 = llm.invoke(messages1)
print(response1.content)
# Out:
# 목표 주가는 여러 요인에 따라 달라질 수 있습니다. 기업의 재무 상태, 산업 동향, 경제 전반의 상황, 그리고 기술적 분석 등이 그 요인들입니다. 특정 주식이나 산업군에 대한 정보를 제공해 주시면, 그에 따른 목표 주가를 예측하는 데 도움을 드릴 수 있습니다. 어떤 주식에 대해 이야기하고 싶으신가요?

# %% [markdown]
# # 메시지 히스토리 직접 관리

# %%
messages = [
    SystemMessage(content="당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다."),
    HumanMessage(content="삼성전자 주식을 지금 매수해도 될까요?")
]

response = llm.invoke(messages)
messages.append(response)  # AI 응답을 히스토리에 추가
# Out:
# SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={})

# %%
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식 매수 여부는 여러 요소에 따라 다릅니다. 고려해야 할 주요 사항은 다음과 같습니다:\n\n1. **기본적 분석**: 삼성전자의 재무제표, 수익 성장률, 배당금 지급 정책 등을 검토해야 합니다. 최근의 수익 보고서와 전망을 확인해 보세요.\n\n2. **산업 동향**: 반도체 산업과 IT 기기 시장의 전반적인 동향을 살펴보십시오. 특히 반도체 수요가 어떻게 변화하고 있는지, 경쟁사가 어떤 전략을 취하고 있는지 확인하는 것이 중요합니다.\n\n3. **경제적 환경**: 금리, 환율, 글로벌 경제 성장 등을 고려하여 삼성전자의 해외 매출에 미치는 영향도 생각해야 합니다.\n\n4. **기술적 분석**: 주가 차트를 통한 기술적 분석으로 가격 추세 및 지지선, 저항선을 파악하세요. 현재 가격이 저렴한가, 과매도 또는 과매수 상태인지 판단할 수 있습니다.\n\n5. **개인의 투자 전략**: 당신의 투자 기간, 리스크 성향, 목표 수익률 등을 고려하여 결정해야 합니다.\n\n결론적으로, 위의 요소들을 종합적으로 분석한 후에 매수를 결정하는 것이 좋습니다. 주식 투자는 항상 리스크가 따르므로 충분한 정보를 기반으로 신중한 결정을 내리시기 바랍니다. 삼성전자의 현재 상황이나 전망에 대한 추가적인 정보를 원하신다면, 특정 데이터나 분석 결과를 요청해 주세요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 329, 'prompt_tokens': 43, 'total_tokens': 372, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_87ea66f7b4', 'id': 'chatcmpl-DSDTcCP8iXbVKix9GhnVvQbGdxImP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0a-cd01-7432-b883-31814aa7383b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 329, 'total_tokens': 372, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
# 후속 질문 (이전 맥락 유지)
messages.append(HumanMessage(content="그렇다면 목표 주가는 얼마로 보시나요?"))

# %%
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식 매수 여부는 여러 요소에 따라 다릅니다. 고려해야 할 주요 사항은 다음과 같습니다:\n\n1. **기본적 분석**: 삼성전자의 재무제표, 수익 성장률, 배당금 지급 정책 등을 검토해야 합니다. 최근의 수익 보고서와 전망을 확인해 보세요.\n\n2. **산업 동향**: 반도체 산업과 IT 기기 시장의 전반적인 동향을 살펴보십시오. 특히 반도체 수요가 어떻게 변화하고 있는지, 경쟁사가 어떤 전략을 취하고 있는지 확인하는 것이 중요합니다.\n\n3. **경제적 환경**: 금리, 환율, 글로벌 경제 성장 등을 고려하여 삼성전자의 해외 매출에 미치는 영향도 생각해야 합니다.\n\n4. **기술적 분석**: 주가 차트를 통한 기술적 분석으로 가격 추세 및 지지선, 저항선을 파악하세요. 현재 가격이 저렴한가, 과매도 또는 과매수 상태인지 판단할 수 있습니다.\n\n5. **개인의 투자 전략**: 당신의 투자 기간, 리스크 성향, 목표 수익률 등을 고려하여 결정해야 합니다.\n\n결론적으로, 위의 요소들을 종합적으로 분석한 후에 매수를 결정하는 것이 좋습니다. 주식 투자는 항상 리스크가 따르므로 충분한 정보를 기반으로 신중한 결정을 내리시기 바랍니다. 삼성전자의 현재 상황이나 전망에 대한 추가적인 정보를 원하신다면, 특정 데이터나 분석 결과를 요청해 주세요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 329, 'prompt_tokens': 43, 'total_tokens': 372, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_87ea66f7b4', 'id': 'chatcmpl-DSDTcCP8iXbVKix9GhnVvQbGdxImP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0a-cd01-7432-b883-31814aa7383b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 329, 'total_tokens': 372, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='그렇다면 목표 주가는 얼마로 보시나요?', additional_kwargs={}, response_metadata={})]

# %%
response = llm.invoke(messages)
response
# Out:
# AIMessage(content='삼성전자의 목표 주가는 여러 요인에 따라 달라질 수 있으며, 특정 금액을 제시하는 것은 현재 시장 상황과 다양한 변수에 따라 유동적입니다. 목표 주가를 설정할 때 고려할 수 있는 몇 가지 주요 요소는 다음과 같습니다:\n\n1. **재무 성과**: 삼성전자의 분기별 및 연간 실적을 바탕으로 예상 수익, 이익률 및 성장률을 분석합니다.\n\n2. **산업 변화**: 반도체 시장의 변화(예: 수요 변화, 가격 변동), 스마트폰 및 기타 전자 기기 시장의 동향과 전망이 영향을 미칩니다.\n\n3. **경쟁 분석**: 다른 글로벌 기업들과의 비교를 통해 삼성전자의 경쟁력을 평가하는 것이 중요합니다.\n\n4. **시장 심리**: 투자자들의 심리와 시장의 전반적인 분위기도 주가에 큰 영향을 미칩니다.\n\n5. **모델 기반 접근**: P/E 비율, DCF(Discounted Cash Flow) 모델 등을 사용하여 적정 주가를 산출할 수 있습니다.\n\n이 모든 요소들의 종합적인 분석을 통해 목표 주가를 설정할 수 있지만, 전문가마다 다르게 예측할 수 있으며, 시장의 변동성이 높기 때문에 예측에 신중해야 합니다.\n\n최신 시장 보고서나 전문가의 분석을 참고하면 보다 구체적인 목표 주가를 제시받을 수 있습니다. 만약 구체적인 수치가 필요하다면, 최근 보고서나 전문가 의견을 참고하시길 추천합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 333, 'prompt_tokens': 392, 'total_tokens': 725, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_fd4c9d2a08', 'id': 'chatcmpl-DSDUmL2Sr7HySSXW9ePgwK5CThyOR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0b-e6db-7fa0-8f5f-20c01f6a0531-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 392, 'output_tokens': 333, 'total_tokens': 725, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
messages.append(response)
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식 매수 여부는 여러 요소에 따라 다릅니다. 고려해야 할 주요 사항은 다음과 같습니다:\n\n1. **기본적 분석**: 삼성전자의 재무제표, 수익 성장률, 배당금 지급 정책 등을 검토해야 합니다. 최근의 수익 보고서와 전망을 확인해 보세요.\n\n2. **산업 동향**: 반도체 산업과 IT 기기 시장의 전반적인 동향을 살펴보십시오. 특히 반도체 수요가 어떻게 변화하고 있는지, 경쟁사가 어떤 전략을 취하고 있는지 확인하는 것이 중요합니다.\n\n3. **경제적 환경**: 금리, 환율, 글로벌 경제 성장 등을 고려하여 삼성전자의 해외 매출에 미치는 영향도 생각해야 합니다.\n\n4. **기술적 분석**: 주가 차트를 통한 기술적 분석으로 가격 추세 및 지지선, 저항선을 파악하세요. 현재 가격이 저렴한가, 과매도 또는 과매수 상태인지 판단할 수 있습니다.\n\n5. **개인의 투자 전략**: 당신의 투자 기간, 리스크 성향, 목표 수익률 등을 고려하여 결정해야 합니다.\n\n결론적으로, 위의 요소들을 종합적으로 분석한 후에 매수를 결정하는 것이 좋습니다. 주식 투자는 항상 리스크가 따르므로 충분한 정보를 기반으로 신중한 결정을 내리시기 바랍니다. 삼성전자의 현재 상황이나 전망에 대한 추가적인 정보를 원하신다면, 특정 데이터나 분석 결과를 요청해 주세요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 329, 'prompt_tokens': 43, 'total_tokens': 372, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_87ea66f7b4', 'id': 'chatcmpl-DSDTcCP8iXbVKix9GhnVvQbGdxImP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0a-cd01-7432-b883-31814aa7383b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 329, 'total_tokens': 372, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='그렇다면 목표 주가는 얼마로 보시나요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자의 목표 주가는 여러 요인에 따라 달라질 수 있으며, 특정 금액을 제시하는 것은 현재 시장 상황과 다양한 변수에 따라 유동적입니다. 목표 주가를 설정할 때 고려할 수 있는 몇 가지 주요 요소는 다음과 같습니다:\n\n1. **재무 성과**: 삼성전자의 분기별 및 연간 실적을 바탕으로 예상 수익, 이익률 및 성장률을 분석합니다.\n\n2. **산업 변화**: 반도체 시장의 변화(예: 수요 변화, 가격 변동), 스마트폰 및 기타 전자 기기 시장의 동향과 전망이 영향을 미칩니다.\n\n3. **경쟁 분석**: 다른 글로벌 기업들과의 비교를 통해 삼성전자의 경쟁력을 평가하는 것이 중요합니다.\n\n4. **시장 심리**: 투자자들의 심리와 시장의 전반적인 분위기도 주가에 큰 영향을 미칩니다.\n\n5. **모델 기반 접근**: P/E 비율, DCF(Discounted Cash Flow) 모델 등을 사용하여 적정 주가를 산출할 수 있습니다.\n\n이 모든 요소들의 종합적인 분석을 통해 목표 주가를 설정할 수 있지만, 전문가마다 다르게 예측할 수 있으며, 시장의 변동성이 높기 때문에 예측에 신중해야 합니다.\n\n최신 시장 보고서나 전문가의 분석을 참고하면 보다 구체적인 목표 주가를 제시받을 수 있습니다. 만약 구체적인 수치가 필요하다면, 최근 보고서나 전문가 의견을 참고하시길 추천합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 333, 'prompt_tokens': 392, 'total_tokens': 725, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_fd4c9d2a08', 'id': 'chatcmpl-DSDUmL2Sr7HySSXW9ePgwK5CThyOR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0b-e6db-7fa0-8f5f-20c01f6a0531-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 392, 'output_tokens': 333, 'total_tokens': 725, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
travel_messages = [
    SystemMessage(content="당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다."), 
    HumanMessage(content="부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.")
]

# %%
with get_openai_callback() as cb:
    response = llm.invoke(travel_messages)
    travel_messages.append(response)

    print(f'token 사용량 : {cb.total_tokens}')

# %%
total_tokens_list = []

with get_openai_callback() as cb:
    response = llm.invoke(travel_messages)
    travel_messages.append(response)
    for message in travel_messages:
        print(type(message), message)
    total_tokens_list.append(cb.total_tokens)
    print(f'token 사용량 : {cb.total_tokens}')
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산 여행에서 딱 한 곳만 가봐야 한다면 "해운대 해수욕장"을 추천합니다. 해운대 해수욕장은 부산에서 가장 유명한 해변으로, 아름다운 바다 경관과 함께 다양한 편의시설이 마련되어 있어 많은 관광객들이 찾는 명소입니다. 해수욕 외에도 근처에 다양한 맛집과 카페, 그리고 해운대 마리나, 동백섬 등 볼거리가 많아 즐거운 시간을 보낼 수 있습니다. 여름철에는 해수욕과 야경, 겨울철에는 해운대의 차가운 바닷바람 속에서의 산책도 매력적입니다. 해운대 해수욕장은 부산의 대표적인 매력을 느낄 수 있는 장소입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 49, 'total_tokens': 218, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a5086b7b9a', 'id': 'chatcmpl-DSDgXGJEGqHKjnwENA87MB7CB6RZO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b17-05e5-7642-bc71-621dc50c91ed-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 49, 'output_tokens': 169, 'total_tokens': 218, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# token 사용량 : 218

# %%
with get_openai_callback() as cb:
    travel_messages.append(HumanMessage(content="부산역에서 그곳에 가는 교통편을 알려주세요."))
    response = llm.invoke(travel_messages)
    travel_messages.append(response)
    for message in travel_messages:
        print(type(message), message)
    total_tokens_list.append(cb.total_tokens)
    print(f'token 사용량 : {cb.total_tokens}')
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산 여행에서 딱 한 곳만 가봐야 한다면 "해운대 해수욕장"을 추천합니다. 해운대 해수욕장은 부산에서 가장 유명한 해변으로, 아름다운 바다 경관과 함께 다양한 편의시설이 마련되어 있어 많은 관광객들이 찾는 명소입니다. 해수욕 외에도 근처에 다양한 맛집과 카페, 그리고 해운대 마리나, 동백섬 등 볼거리가 많아 즐거운 시간을 보낼 수 있습니다. 여름철에는 해수욕과 야경, 겨울철에는 해운대의 차가운 바닷바람 속에서의 산책도 매력적입니다. 해운대 해수욕장은 부산의 대표적인 매력을 느낄 수 있는 장소입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 49, 'total_tokens': 218, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a5086b7b9a', 'id': 'chatcmpl-DSDgXGJEGqHKjnwENA87MB7CB6RZO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b17-05e5-7642-bc71-621dc50c91ed-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 49, 'output_tokens': 169, 'total_tokens': 218, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 해운대 해수욕장으로 가는 교통편은 다음과 같습니다:\n\n1. **지하철**:\n   - **부산 지하철 1호선**을 타고 **동래역**에서 **부산 지하철 2호선**으로 환승합니다. \n   - 동래역에서 2호선으로 갈아탄 뒤, **해운대역**에서 하차합니다. \n   - 해운대역 3번 출구로 나와 도보로 약 5~10분이면 해운대 해수욕장에 도착할 수 있습니다.\n\n2. **버스**:\n   - 부산역 근처에서 1003번 고속버스를 타고 **해운대 해수욕장** 정류장에서 하차합니다. \n   - 버스 이용 시 교통 상황에 따라 소요 시간이 다를 수 있습니다.\n\n3. **택시**:\n   - 부산역에서 택시를 이용할 경우, 약 30분 정도 소요되며, 요금은 대략 15,000원에서 20,000원 정도입니다. \n\n이러한 방법으로 부산역에서 해운대 해수욕장까지 편리하게 이동할 수 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 268, 'prompt_tokens': 242, 'total_tokens': 510, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8b6cd59583', 'id': 'chatcmpl-DSDh8d3bDHohw0Bevpa1bmqsc8DkM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b17-95d4-7f31-83c7-8a78b8bb1414-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 242, 'output_tokens': 268, 'total_tokens': 510, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# token 사용량 : 510

# %%
with get_openai_callback() as cb:
    travel_messages.append(HumanMessage(content="그 근처에 먹을 만한 음식점들을 추천해주세요."))
    response = llm.invoke(travel_messages)
    travel_messages.append(response)
    for message in travel_messages:
        print(type(message), message)
    total_tokens_list.append(cb.total_tokens)
    print(f'token 사용량 : {cb.total_tokens}')
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산 여행에서 딱 한 곳만 가봐야 한다면 "해운대 해수욕장"을 추천합니다. 해운대 해수욕장은 부산에서 가장 유명한 해변으로, 아름다운 바다 경관과 함께 다양한 편의시설이 마련되어 있어 많은 관광객들이 찾는 명소입니다. 해수욕 외에도 근처에 다양한 맛집과 카페, 그리고 해운대 마리나, 동백섬 등 볼거리가 많아 즐거운 시간을 보낼 수 있습니다. 여름철에는 해수욕과 야경, 겨울철에는 해운대의 차가운 바닷바람 속에서의 산책도 매력적입니다. 해운대 해수욕장은 부산의 대표적인 매력을 느낄 수 있는 장소입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 49, 'total_tokens': 218, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a5086b7b9a', 'id': 'chatcmpl-DSDgXGJEGqHKjnwENA87MB7CB6RZO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b17-05e5-7642-bc71-621dc50c91ed-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 49, 'output_tokens': 169, 'total_tokens': 218, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 해운대 해수욕장으로 가는 교통편은 다음과 같습니다:\n\n1. **지하철**:\n   - **부산 지하철 1호선**을 타고 **동래역**에서 **부산 지하철 2호선**으로 환승합니다. \n   - 동래역에서 2호선으로 갈아탄 뒤, **해운대역**에서 하차합니다. \n   - 해운대역 3번 출구로 나와 도보로 약 5~10분이면 해운대 해수욕장에 도착할 수 있습니다.\n\n2. **버스**:\n   - 부산역 근처에서 1003번 고속버스를 타고 **해운대 해수욕장** 정류장에서 하차합니다. \n   - 버스 이용 시 교통 상황에 따라 소요 시간이 다를 수 있습니다.\n\n3. **택시**:\n   - 부산역에서 택시를 이용할 경우, 약 30분 정도 소요되며, 요금은 대략 15,000원에서 20,000원 정도입니다. \n\n이러한 방법으로 부산역에서 해운대 해수욕장까지 편리하게 이동할 수 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 268, 'prompt_tokens': 242, 'total_tokens': 510, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8b6cd59583', 'id': 'chatcmpl-DSDh8d3bDHohw0Bevpa1bmqsc8DkM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b17-95d4-7f31-83c7-8a78b8bb1414-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 242, 'output_tokens': 268, 'total_tokens': 510, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='그 근처에 먹을 만한 음식점들을 추천해주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='해운대 해수욕장 근처에는 다양한 맛집이 많습니다. 몇 가지 추천할 만한 음식점을 소개해드리겠습니다:\n\n1. **해운대 구룡포식당**:\n   - 해산물 전문 식당으로 싱싱한 회와 해물탕이 인기입니다. 바다 경치를 보면서 식사할 수 있는 좋은 위치에 있습니다.\n\n2. **밀면**:\n   - 부산의 대표적인 면 요리인 밀면을 맛볼 수 있는 곳입니다. 얼음육수와 함께 먹는 시원한 면 요리는 여름철에 특히 인기가 많습니다.\n\n3. **이기대식당**:\n   - 해물 요리가 유명한 곳으로, 다양한 해산물 요리를 제공합니다. 신선한 재료로 만든 음식이 일품입니다.\n\n4. **해운대 포장마차 거리**:\n   - 해운대에서 유명한 포장마차 거리에서는 다양한 길거리 음식을 즐길 수 있습니다. 오징어 구이, 고등어 구이, 떡볶이, 튀김 등 다양한 메뉴가 있습니다.\n\n5. **부산횟집**:\n   - 신선한 회를 제공하는 횟집으로, 가격대가 다양해 선택의 폭이 넓습니다. 바다 전망과 함께 식사를 즐길 수 있는 곳입니다.\n\n6. **돔베돈**:\n   - 돼지고기 전문점으로, 제주도 스타일의 흑돼지 구이가 유명합니다. 고기와 함께 나오는 여러 가지 사이드 메뉴도 일품입니다.\n\n이 외에도 많은 맛집들이 있으니, 해운대 해변을 산책하며 다양한 음식을 탐방해보시는 것도 좋은 경험이 될 것입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 373, 'prompt_tokens': 532, 'total_tokens': 905, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8b6cd59583', 'id': 'chatcmpl-DSDhhaO9hc4m58SPS8NaUv9NqXSrk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b18-1f8d-7b02-8830-97b1df38668c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 532, 'output_tokens': 373, 'total_tokens': 905, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# token 사용량 : 905

# %%
# 토큰사용량 체크

print(f'token 사용현황 : {total_tokens_list}')
# Out:
# token 사용현황 : [218, 510, 905]

# %% [markdown]
# # 랭체인의 대화히스토리 관리 객체 사용하기

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

llm = ChatOpenAI(model="gpt-4o-mini")

prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 주식 투자 전문가입니다."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}")
])

chain = prompt | llm
# Out:
# c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\jinja2\sandbox.py:177: RuntimeWarning: coroutine 'invoke_async' was never awaited
#   class SandboxedEnvironment(Environment):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
# 세션별 히스토리 저장소
store = {}

def get_session_history(session_id: str):
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

chain_with_history = RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="history"
)

# %%
# 첫 번째 질문 (runnable chain)
response = chain_with_history.invoke(
    {"input": "삼성전자 주식을 지금 매수해도 될까요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자 주식의 매수 여부를 결정하기 위해 고려해야 할 여러 요소가 있습니다.
#
# 1. **재무 성과**: 삼성전자의 최근 분기 보고서와 연간 실적을 살펴보세요. 매출, 순이익, 부채 비율 등이 긍정적인지 확인해야 합니다.
#
# 2. **시장 동향**: 전 세계 반도체 산업의 현재 상황과 전망, 그리고 스마트폰 시장의 트렌드를 분석해보세요. 수요 증가 또는 감소에 따라 주가에 영향을 미칠 수 있습니다.
#
# 3. **경쟁 상황**: 대만의 TSMC, 미국의 인텔, 그리고 중국의 반도체 기업들과의 경쟁 현황도 중요합니다.
#
# 4. **경제 전반**: 한국 및 글로벌 경제의 전반적인 상황, 금리 변화, 인플레이션 등도 주가에 영향을 미칠 수 있습니다.
#
# 5. **기타 투자 요소**: 개인의 투자 목표와 리스크 수용 능력도 고려해야 합니다. 장기 투자와 단기 투자 전략이 다를 수 있습니다.
#
# 결론적으로, 삼성전자 주식을 매수하기 전 위의 요소들을 충분히 분석하고, 필요시 전문가와 상담하는 것이 좋습니다.

# %%
response = chain_with_history.invoke(
    {"input": "그렇다면 목표 주가는 얼마로 보시나요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자의 목표 주가는 여러 요인에 따라 달라질 수 있습니다. 목표 주가를 설정하는 데는 다음과 같은 요소들이 고려될 수 있습니다:
#
# 1. **재무 지표**: PE 비율(주가수익비율), PS 비율(주가매출비율), EV/EBITDA 등 다양한 재무 지표를 분석하여 적정 주가를 산출할 수 있습니다.
#
# 2. **산업 전망**: 반도체 산업과 같은 주요 사업 분야의 성장 가능성 및 경쟁 상황 조사.
#
# 3. **기술 혁신**: 삼성전자의 연구 개발(R&D) 결과물이나 신제품 출시가 매출에 미치는 영향 예측.
#
# 4. **글로벌 경제**: 경제 성장률, 인플레이션, 금리 등의 외부 요인도 중요합니다.
#
# 5. **애널리스트 의견**: 다양한 금융 기관이나 애널리스트들이 제시하는 목표 주가를 참고할 수도 있습니다.
#
# 정확한 목표 주가는 현재의 시장 환경, 향후 전망, 회사의 전략 및 기타 경제적 요인에 따라 달라지기 때문에, 구체적인 숫자를 제시하는 것은 어렵습니다. 최신 정보를 검토하고, 전문가의 분석을 참고하여 개인적으로 판단하는 것이 좋습니다.
#
# 또한, 투자 결정을 내리기 전 전문가와 상담하거나 상세한 리서치를 진행하는 것이 중요합니다.

# %%
response = chain_with_history.invoke(
    {"input": "그렇다면, 주가의 위험요소는 무엇인가요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자의 주가에 영향을 미칠 수 있는 여러 위험 요소가 있습니다. 이 위험 요소들은 투자 결정을 내릴 때 중요한 고려 사항이 될 수 있습니다. 주요 위험 요소는 다음과 같습니다:
#
# 1. **시장 변동성**: 글로벌 경제 및 증시의 변화에 따라 삼성전자의 주가는 크게 변동할 수 있습니다. 특히 금리 인상, 인플레이션 상승 등의 macroeconomic 이슈가 주가에 영향을 미칠 수 있습니다.
#
# 2. **산업 경쟁**: 반도체 및 스마트폰 산업에서의 경쟁 심화는 삼성전자의 시장 점유율 및 마진에 부정적인 영향을 미칠 수 있습니다. TSMC, 인텔, 애플 등 경쟁업체들의 성장도 주가에 영향을 줄 수 있습니다.
#
# 3. **기술 변화**: 기술의 빠른 변화는 회사의 제품 경쟁력을 저하시킬 수 있습니다. 예를 들어, 인공지능, 5G, 자율주행차 등 새로운 기술의 도입은 기업 전략에 큰 변화를 요구할 수 있습니다.
#
# 4. **정치적 및 경제적 불확실성**: 한국 및 글로벌 정치 상황 (예: 무역 갈등, 규제 변경 등)이나 자연재해, 전염병(예: COVID-19) 등의 외부 충격이 기업 운영에 영향을 미칠 수 있습니다.
#
# 5. **환율 변동**: 삼성전자는 해외 매출 비중이 크기 때문에 환율 변동으로 인한 수익 변동 가능성이 큽니다. 원화 강세는 해외 매출을 감소시키고, 반대로 원화 약세는 해외 수익을 증가시킬 수 있습니다.
#
# 6. **공급망 문제**: 글로벌 공급망의 중단이나 원자재 가격 상승은 생산비용을 증가시켜 기업의 수익성에 부정적인 영향을 미칠 수 있습니다.
#
# 7. **법적 및 규제 리스크**: 반독점 법규, 개인정보 보호법 등의 법적 리스크가 회사 운영에 부정적인 영향을 줄 수 있습니다.
#
# 위험 요소를 잘 이해하고 관리하는 것이 중요합니다. 각 요소들이 삼성전자의 사업 모델과 어떻게 연결되는지를 살펴보고, 적절한 투자 전략을 세우는 것이 필요합니다.

# %%
response = chain_with_history.invoke(
    {"input": "그렇다면, 주가의 위험요소는 무엇인가요?"},
    config={"configurable": {"session_id": "user_002"}}
)
print(response.content)
# Out:
# 주가의 위험 요소는 여러 가지가 있으며, 주식 투자자들이 고려해야 할 중요한 요소들입니다. 주요 위험 요소는 다음과 같습니다:
#
# 1. **시장 리스크**: 전체 시장의 변동성으로 인해 주가가 영향을 받는 위험입니다. 경제 전반의 경기변동, 금리 변화, 글로벌 사건 등이 이에 해당합니다.
#
# 2. **기업 리스크**: 특정 기업의 재무 상태나 경영 전략, 경쟁 상황에 따라 주가가 영향을 받을 수 있습니다. 이는 기업의 실적 발표, 뉴스, 사건 사고 등으로 인해 발생할 수 있습니다.
#
# 3. **산업 리스크**: 특정 산업의 특성이나 트렌드에 따라 주가가 영향을 받을 수 있습니다. 예를 들어, 기술 산업의 경우 빠른 기술 변화가 큰 영향을 미칠 수 있습니다.
#
# 4. **신용 리스크**: 기업의 부도 위험을 나타냅니다. 신용 등급이 낮아지거나 재무 상태가 악화되면 주가가 하락할 수 있습니다.
#
# 5. **금리 리스크**: 금리가 상승하면 자본 비용이 증가하고, 이는 기업의 수익성에 영향을 미쳐 주가에 부정적인 영향을 줄 수 있습니다.
#
# 6. **환율 리스크**: 해외 수익을 가지는 기업의 경우 환율 변동이 주가에 영향을 미칠 수 있습니다. 외환 시장의 변동성은 해외 매출에 영향을 줄 수 있습니다.
#
# 7. **정치적 리스크**: 정치적 불안정성, 정책 변화, 규제의 강화 또는 약화가 주가에 영향을 미치는 경우입니다.
#
# 8. **자연재해 및 비상사태**: 전염병, 자연재해 등 예기치 못한 사건들이 기업 운영에 영향을 줄 수 있습니다.
#
# 이러한 위험 요소들은 주식 투자자들이 투자 결정을 내릴 때 신중하게 고려해야 할 사항입니다. 각 투자자의 리스크 감내도와 투자 전략에 따라 이러한 요소들의 중요성은 다르게 평가될 수 있습니다.

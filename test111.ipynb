# %%
print("테스트입니다. 테스트입니다.")
# Out:
# 테스트입니다. 테스트입니다.

# %%
#테스트입니다.테스트입니다.
3*4
# Out:
# 12

# %%
# 주석
# 주석333
# 주석5555
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 주석
#       2 주석333
#       3 주석5555
#
# NameError: name '주석' is not defined

# %%
"안녕하세요1." 
"안녕하세요.2 "
# Out:
# '안녕하세요.2 '

# %%
print("안녕하세요")
print("안녕2")
# Out:
# 안녕하세요
# 안녕2

# %%
"""테스트입니다.
테스트입니다."""
# Out:
# '테스트입니다.\n테스트입니다.'

# %%
def calculate_sum(a, b):
    result = a + b    # 들여쓰기된 코드 블록
    return result     # 같은 레벨의 들여쓰기

if result > 0:
    print("양수입니다")    # if문 내부의 들여쓰기된 코드
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2     result = a + b    # 들여쓰기된 코드 블록
#       3     return result     # 같은 레벨의 들여쓰기
# ----> 5 if result > 0:
#       6     print("양수입니다")    # if문 내부의 들여쓰기된 코드
#
# NameError: name 'result' is not defined

# %%
def calculate_sum(a, b):
    result = a + b    # 들여쓰기된 코드 블록
    return result     # 같은 레벨의 들여쓰기

# %%
def calculate_sum(a, b):
    result = a + b    # 들여쓰기된 코드 블록
    return result     # 같은 레벨의 들여쓰기

result=calculate_sum(3,8)

if result > 0:
    print("양수입니다")    # if문 내부의 들여쓰기된 코드
# Out:
# 양수입니다

# %%
def calculate_sum(a, b):
    result = a + b    # 들여쓰기된 코드 블록
    return result     # 같은 레벨의 들여쓰기

result=calculate_sum(3,-8)

if result > 0:
    print("양수입니다")    # if문 내부의 들여쓰기된 코드

# %%
def calculate_sum(a, b):
    result = a + b    # 들여쓰기된 코드 블록
    return result     # 같은 레벨의 들여쓰기

result=calculate_sum(3,-4)

if result > 0:
    print(result)    
    print("양수입니다")    # if문 내부의 들여쓰기된 코드

# %%
print(result)
# Out:
# 0

# %% [markdown]
# #안녕하세요. 안녕하세요.

# %% [markdown]
# #안녕하세요.

# %% [markdown]
# #안녕하세요.

# %% [markdown]
# #안녕하세요.

# %% [markdown]
# # 안녕하세요.

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ## 안녕하세요.

# %% [markdown]
# ### 안녕하세요333

# %% [markdown]
# #### 안녕하세요444

# %% [markdown]
# ##### 안녕하세요5

# %% [markdown]
# * 하나
# * 둘
# * 셋

# %% [markdown]
# 1. one
# 2. two
# 3. three

# %% [markdown]
# * 첫번째
# - 서브리스트1
#     - 아이템1
#     - 아이템2
#
# - 서비스리트2
#     - 아이템3
#
# * 두번째
# - 서브리스트3

# %% [markdown]
# * 첫번째
#     - 서브리스트1
#           - 아이템1
#           - 아이템2
#     - 서브리스트2
#         - 아이템3

# %% [markdown]
# * 첫번째
#     - 서브리스트1
#           - 아이템1
#           - 아이템2

# %% [markdown]
# * 첫번째
#   - 서브리스트1
#     - 아이템1

# %% [markdown]
# 1. 안녕
# 2. 반가워

# %% [markdown]
# ## 🐍 파이썬(Python) vs ☕ 자바(Java) 비교
#
# 파이썬과 자바는 각각의 장점이 뚜렷한 언어입니다. 주요 차이점을 아래 표로 확인해 보세요.
#
# | 비교 항목 | 파이썬 (Python) | 자바 (Java) |
# | :--- | :--- | :--- |
# | **언어 특징** | 인터프리터 언어 (Script) | 컴파일 언어 (JVM 기반) |
# | **타이핑** | **동적 타이핑** (런타임 시 결정) | **정적 타이핑** (컴파일 시 결정) |
# | **문법** | 간결하고 직관적 (들여쓰기 강제) | 정교하고 엄격함 (중괄호 사용) |
# | **속도** | 느린 편 (인터프리터 방식) | 빠른 편 (JIT 컴파일러) |
# | **생산성** | 매우 높음 (코드 길이가 짧음) | 보통 (설계 및 작성 시간이 걸림) |
# | **멀티쓰레딩** | GIL로 인해 제약이 있음 | 멀티쓰레딩 지원이 강력함 |
# | **주요 활용** | AI, 데이터 과학, 웹 크롤링 | 백엔드 시스템, 안드로이드 앱, 금융 |
# | **프레임워크** | Django, FastAPI, PyTorch | Spring, Hibernate, Struts |
#
# ---
#
# ### 💡 한 줄 요약
# * **파이썬:** "빠르게 아이디어를 구현하고 데이터 분석이나 AI 모델을 만들고 싶을 때" 추천합니다.
# * **자바:** "규모가 크고 안정성이 중요한 기업형 시스템이나 안드로이드 앱을 만들 때" 추천합니다.

# %% [markdown]
# <div align="center">
# ** 개구리 점프**
#    </div>
#
# <p align="center">
#
# | 번호 | 이름 |
# |------|------|
# |1     | 개구리 |
# |2     | 도마뱀 |
#
# ![개구리이미지](https://cdn.crowdpic.net/detail-thumb/thumb_d_C483CA98284F3529BA6FB246EE93B74B.png)

# %%
#시각화 라이브러리 설치

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import seaborn as sns
#       2 anscombe = sns.load_dataset('anscombe')
#       3 anscombe
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#폰트 지정
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim'
rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
plt.title('클래스와 오브젝트')
plt.xlabel('클래스')
plt.ylabel('오브젝트')
# Out:
# Text(0, 0.5, '오브젝트')

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
import matplotlib.pyplot as plt

# %%
d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']

# %%
d1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
d2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
d3.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
d4.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
plt.plot(d1['x'], d1['y'])

# %%
plt.plot(d2['x'], d2['y'])

# %%
plt.plot(d1['x'], d1['y'], 'o')

# %%
plt.plot(d2['x'], d2['y'], 'o')

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1) #2row, 2col,position
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot( d1['x'], d1['y'] , 'o')
axes2.plot( d2['x'], d2['y'] , 'o')
axes3.plot( d3['x'], d3['y'] , 'o')
axes4.plot( d4['x'], d4['y'] , 'o')

axes1.set_title('dataset I')
axes2.set_title('dataset II')
axes3.set_title('dataset III')
axes4.set_title('dataset IV')

fig.suptitle('Anscombe Dataset 으로 보는 데이터 시각화의 의미')
fig.set_tight_layout(True)
plt.show()

# %%
dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

# %%
plt.plot(dates,prices)

# %%
plt.figure(figsize=(10,6)) #차트의 크기
plt.plot (dates, prices, marker='o')

# %%
plt.figure(figsize=(10,6)) #차트의 크기
plt.plot (dates, prices, marker='o')
plt.title('테스트타이틀')
plt.legend('범례')
plt.xlabel('x축')
plt.ylabel('y축')
plt.grid('그리드')

# %%
plt.subplot(1,2,1)
plt.plot(dates, prices, marker='o')

plt.subplot(1,2,2)
plt.bar (dates, prices)
plt.savefig('my_chart.png')

# %%
#용도에 따른 차트 그리기

# %%
tips_df=sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#1변량 그래프: 히스토그램- 구간과 빈도수를 나타낸다.

# %%
plt.hist(data=tips_df, x='total_bill', bins=10, rwidth=0.8)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
#total bill과 tip 비교

# %%
plt.subplot (1,2,1)
plt.hist(data=tips_df, x='total_bill', bins=10, rwidth=0.8, color='red')
plt.subplot (1,2,2)
plt.hist(data=tips_df, x='tip', bins=10, rwidth=0.8)
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
#1변량 그래프: 박스 플롯
plt.boxplot(data=tips_df, x='total_bill')
plt.grid()
plt.show()

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df['sex']=='Female'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 239    False
# 240     True
# 241    False
# 242    False
# 243     True
# Name: sex, Length: 244, dtype: bool

# %%
plt.boxplot(
  [tips_df[tips_df['sex']=='Female']['total_bill'], 
   tips_df[tips_df['sex']=='Female']['tip'],         
  labels=['total_bill/Female', 'tip/Female'])
  
plt.grid()
plt.show()
# Out:
#   Cell In[42], line 4
#     labels=['total_bill/Female', 'tip/Female'])
#                                               ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '[' on line 2

# %%
plt.boxplot(
    [
        tips_df[tips_df['sex'] == 'Female']['total_bill'],
        tips_df[tips_df['sex'] == 'Female']['tip']
    ],
    labels=['total_bill/Female', 'tip/Female']
)

plt.grid()
plt.show()

# %%
plt.boxplot(
    [
        tips_df[tips_df['sex'] == 'male']['total_bill'],
        tips_df[tips_df['sex'] == 'male']['tip']
    ],
    labels=['total_bill/male', 'tip/male']
)

plt.grid()
plt.show()

# %%
plt.boxplot(
    [
        tips_df[tips_df['sex'] == 'Male']['total_bill'],
        tips_df[tips_df['sex'] == 'Male']['tip']
    ],
    labels=['total_bill/Male', 'tip/Male']
)

plt.grid()
plt.show()

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.boxplot(
    [
        tips_df[tips_df['sex']=='Female']['day'],
        tips_df[tips_df['sex']=='male']['day']
   ],
    labels=['day/Female', 'day/male']
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 plt.boxplot(
#       2     [
#       3         tips_df[tips_df['sex']=='Female']['day'],
#       4         tips_df[tips_df['sex']=='male']['day']
#       5    ],
#       6     labels=['day/Female', 'day/male']
#       7 )
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\matplotlib\_api\deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
#     291         since, message=f"The {old!r} parameter of {func.__name__}() "
#     292         f"has been renamed {new!r} since Matplotlib {since}; support "
#     293         f"for the old name will be dropped in %(removal)s.")
#     294     kwargs[new] = kwargs.pop(old)
# --> 295 return func(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\matplotlib\pyplot.py:3085, in boxplot(x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label, data)
#    3051 @_copy_docstring_and_deprecators(Axes.boxplot)
#    3052 def boxplot(
#    3053     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3083     data=None,
#    3084 ) -> dict[str, Any]:
# -> 3085     return gca().boxplot(
#    3086         x,
#    3087         notch=notch,
#    3088         sym=sym,
#    3089         vert=vert,
#    3090         orientation=orientation,
#    3091         whis=whis,
#    3092         positions=positions,
#    3093         widths=widths,
#    3094         patch_artist=patch_artist,
#    3095         bootstrap=bootstrap,
#    3096         usermedians=usermedians,
#    3097         conf_intervals=conf_intervals,
#    3098         meanline=meanline,
#    3099         showmeans=showmeans,
#    3100         showcaps=showcaps,
#    3101         showbox=showbox,
#    3102         showfliers=showfliers,
#    3103         boxprops=boxprops,
#    3104         tick_labels=tick_labels,
#    3105         flierprops=flierprops,
#    3106         medianprops=medianprops,
#    3107         meanprops=meanprops,
#    3108         capprops=capprops,
#    3109         whiskerprops=whiskerprops,
#    3110         manage_ticks=manage_ticks,
#    3111         autorange=autorange,
#    3112         zorder=zorder,
#    3113         capwidths=capwidths,
#    3114         label=label,
#    3115         **({"data": data} if data is not None else {}),
#    3116     )
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\matplotlib\_api\deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
#     291         since, message=f"The {old!r} parameter of {func.__name__}() "
#     292         f"has been renamed {new!r} since Matplotlib {since}; support "
#     293         f"for the old name will be dropped in %(removal)s.")
#     294     kwargs[new] = kwargs.pop(old)
# --> 295 return func(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\matplotlib\axes\_axes.py:4138, in Axes.boxplot(self, x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label)
#    4135 if bootstrap is None:
#    4136     bootstrap = mpl.rcParams['boxplot.bootstrap']
# -> 4138 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    4139                                labels=tick_labels, autorange=autorange)
#    4140 if notch is None:
#    4141     notch = mpl.rcParams['boxplot.notch']
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\matplotlib\cbook.py:1252, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1249 x = x.data[~x.mask].ravel()
#    1251 # arithmetic mean
# -> 1252 stats['mean'] = np.mean(x)
#    1254 # medians and quartiles
#    1255 q1, med, q3 = np.percentile(x, [25, 50, 75])
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\numpy\_core\fromnumeric.py:3860, in mean(a, axis, dtype, out, keepdims, where)
#    3857     else:
#    3858         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3860 return _methods._mean(a, axis=axis, dtype=dtype,
#    3861                       out=out, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\numpy\_core\_methods.py:147, in _mean(a, axis, dtype, out, keepdims, where)
#     145         ret = ret.dtype.type(ret / rcount)
#     146 else:
# --> 147     ret = ret / rcount
#     149 return ret
#
# TypeError: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
plt.boxplot(
    [
        tips_df[tips_df['smoker']=='No']['total_bill'],
        tips_df[tips_df['smoker']=='Yes']['total_bill']
   ],
    labels=['비흡연자쓴금액', '흡연자쓴금액']
)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x206d6ff5ab0>,
#   <matplotlib.lines.Line2D at 0x206d6ff5db0>,
#   <matplotlib.lines.Line2D at 0x206d6ff6fb0>,
#   <matplotlib.lines.Line2D at 0x206d6ff72b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x206d6ff60b0>,
#   <matplotlib.lines.Line2D at 0x206d6ff63b0>,
#   <matplotlib.lines.Line2D at 0x206d6ff75b0>,
#   <matplotlib.lines.Line2D at 0x206d6ff78b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x206d6ff48b0>,
#   <matplotlib.lines.Line2D at 0x206d6ff6cb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x206d6ff66b0>,
#   <matplotlib.lines.Line2D at 0x206d6ff7bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x206d6ff69b0>,
#   <matplotlib.lines.Line2D at 0x206d6ff7eb0>],
#  'means': []}

# %%
plt.boxplot(
    [
        tips_df[tips_df['smoker']=='No']['tip'],
        tips_df[tips_df['smoker']=='Yes']['tip']
   ],
    labels=['비흡연자팁', '흡연자팁']
)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x206d704f250>,
#   <matplotlib.lines.Line2D at 0x206d704f550>,
#   <matplotlib.lines.Line2D at 0x206d706c790>,
#   <matplotlib.lines.Line2D at 0x206d706ca90>],
#  'caps': [<matplotlib.lines.Line2D at 0x206d704f850>,
#   <matplotlib.lines.Line2D at 0x206d704fb50>,
#   <matplotlib.lines.Line2D at 0x206d706cd90>,
#   <matplotlib.lines.Line2D at 0x206d706d090>],
#  'boxes': [<matplotlib.lines.Line2D at 0x206d704d300>,
#   <matplotlib.lines.Line2D at 0x206d706c490>],
#  'medians': [<matplotlib.lines.Line2D at 0x206d704fe50>,
#   <matplotlib.lines.Line2D at 0x206d706d390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x206d706c190>,
#   <matplotlib.lines.Line2D at 0x206d706d690>],
#  'means': []}

# %%
plt.subplot (1,2,1)
plt.boxplot(
    [
        tips_df[tips_df['smoker']=='No']['total_bill'],
        tips_df[tips_df['smoker']=='Yes']['total_bill']
   ],
    labels=['비흡연자쓴금액', '비흡연자쓴금액']
)
plt.subplot (1,2,2)
plt.boxplot(
    [
        tips_df[tips_df['smoker']=='No']['tip'],
        tips_df[tips_df['smoker']=='Yes']['tip']
   ],
    labels=['비흡연자팁', '흡연자팁']
)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x206d711cbe0>,
#   <matplotlib.lines.Line2D at 0x206d711cdc0>,
#   <matplotlib.lines.Line2D at 0x206d711dfc0>,
#   <matplotlib.lines.Line2D at 0x206d711e2c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x206d711d0c0>,
#   <matplotlib.lines.Line2D at 0x206d711d3c0>,
#   <matplotlib.lines.Line2D at 0x206d711e5c0>,
#   <matplotlib.lines.Line2D at 0x206d711e8c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x206d711c8e0>,
#   <matplotlib.lines.Line2D at 0x206d711dcc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x206d711d6c0>,
#   <matplotlib.lines.Line2D at 0x206d711ebc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x206d711d9c0>,
#   <matplotlib.lines.Line2D at 0x206d711eec0>],
#  'means': []}

# %%
plt.subplot (1,2,1)
plt.boxplot(
    [
        tips_df[tips_df['smoker']=='No']['total_bill'],
        tips_df[tips_df['smoker']=='No']['tipl']
   ],
    labels=['비흡연자가 쓴 금액', '비흡연자가 준 팁']
)
plt.subplot (1,2,2)
plt.boxplot(
    [
        tips_df[tips_df['smoker']=='Yes']['total_bill'],
        tips_df[tips_df['smoker']=='Yes']['tip']
   ],
    labels=['흡연자가 쓴 금액', '흡연자가 준 팁']
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tipl'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 5
#       1 plt.subplot (1,2,1)
#       2 plt.boxplot(
#       3     [
#       4         tips_df[tips_df['smoker']=='No']['total_bill'],
# ----> 5         tips_df[tips_df['smoker']=='No']['tipl']
#       6    ],
#       7     labels=['비흡연자가 쓴 금액', '비흡연자가 준 팁']
#       8 )
#       9 plt.subplot (1,2,2)
#      10 plt.boxplot(
#      11     [
#      12         tips_df[tips_df['smoker']=='Yes']['total_bill'],
#    (...)
#      15     labels=['흡연자가 쓴 금액', '흡연자가 준 팁']
#      16 )
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'tipl'

# %%
plt.subplot (1,2,1)
plt.boxplot(
    [
        tips_df[tips_df['smoker']=='No']['total_bill'],
        tips_df[tips_df['smoker']=='No']['tip']
   ],
    labels=['비흡연자가 쓴 금액', '비흡연자가 준 팁']
)
plt.subplot (1,2,2)
plt.boxplot(
    [
        tips_df[tips_df['smoker']=='Yes']['total_bill'],
        tips_df[tips_df['smoker']=='Yes']['tip']
   ],
    labels=['흡연자가 쓴 금액', '흡연자가 준 팁']
)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x206d84c0f10>,
#   <matplotlib.lines.Line2D at 0x206d84c1210>,
#   <matplotlib.lines.Line2D at 0x206d84c22f0>,
#   <matplotlib.lines.Line2D at 0x206d84c25f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x206d84c1510>,
#   <matplotlib.lines.Line2D at 0x206d84c1810>,
#   <matplotlib.lines.Line2D at 0x206d84c28f0>,
#   <matplotlib.lines.Line2D at 0x206d84c2bf0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x206d84c0c10>,
#   <matplotlib.lines.Line2D at 0x206d84c1ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x206d84c19f0>,
#   <matplotlib.lines.Line2D at 0x206d84c2ef0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x206d84c1cf0>,
#   <matplotlib.lines.Line2D at 0x206d84c31f0>],
#  'means': []}
